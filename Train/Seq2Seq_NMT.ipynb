# %% [markdown]
# #### Neural Machine Translation (NMT) with Attention

# %%
### Import the necessary packages

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import random

# %%
### Create the source vocabulary

# Default word tokens
PAD_token = 0  # Used for padding short number sequences
SOS_token = 1  # Start-of-sequence token
EOS_token = 2  # End-of-sequence token
UNK_token = 3  # Unknown word token

class ASR_Vocab(object):
    def __init__(self, digit_seqs):
        super(ASR_Vocab, self).__init__()
        self.digit2index = {}
        self.digit2count = {}
        self.index2digit = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS", UNK_token: "UNK"}
        
        # Count SOS, EOS, PAD, UNK
        self.num_tokens  = 4
        self.digit_seqs  = digit_seqs
        
    def dig2idx(self, digit):
        if digit in self.digit2index:
            return self.digit2index[digit]
        else:
            return UNK_token
        
    def idx2dig(self, idx):
        if idx in self.index2digit:
            return self.index2digit[idx]
        else:
            return self.index2digit[UNK_token]
            
    def add_digit(self, digit):
        if digit in self.digit2index:
            self.digit2count[digit] += 1
            
        else:
            self.digit2index[digit] = self.num_tokens
            self.index2digit[self.num_tokens] = digit
            self.digit2count[digit] = 1
            self.num_tokens += 1
            
    def build_vocab(self):        
        for seq in self.digit_seqs:
            for digit in seq:      # Ignore EOS token
                self.add_digit(digit)
            
        print("Vocabulary created with %d tokens ..." % self.num_tokens)
        # return self.num_tokens
    
    def vocab_size(self):
        return self.num_tokens
    
    def vocabulary(self):
        for idx in self.index2digit:
            print(idx, self.index2digit[idx])
    
    def encode(self, seq):
        return [self.dig2idx(digit) for digit in seq]
    
    def decode(self, seq):
        return "".join([self.idx2dig(idx) for idx in seq])
    
# Create the vocabulary
with open('../data/ASR/ASR_Labels.txt', 'r') as f:
    asr_labels = f.read().splitlines()
asr_labels = [asr_label[:-1] for asr_label in asr_labels]
    
print("Number of ASR utterances : ", len(asr_labels))
vocab_asr = ASR_Vocab(asr_labels)
vocab_asr.build_vocab()

# Test the vocabulary
print("\nOriginal sequence : ", asr_labels[4])
encoded_seq = vocab_asr.encode(asr_labels[4])
decoded_seq = vocab_asr.decode(encoded_seq)

print("Encoded sequence  : ", encoded_seq)
print("Decoded sequence  : ", decoded_seq)
# Out:
# Number of ASR utterances :  8398
# Vocabulary created with 15 tokens ...
#
# Original sequence :  49Z93Z2
# Encoded sequence  :  [10, 7, 11, 7, 9, 11, 4]
# Decoded sequence  :  49Z93Z2

# %%
### Create the target vocabulary

class MT_Vocab(object):
    def __init__(self, digit_seqs):
        super(MT_Vocab, self).__init__()
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS", UNK_token: "UNK"}
        
        # Count SOS, EOS, PAD, UNK
        self.num_words  = 4
        self.digit_seqs = digit_seqs
        
    def word2idx(self, word):
        if word in self.word2index:
            return self.word2index[word]
        else:
            return UNK_token
        
    def idx2word(self, idx):
        if idx in self.index2word:
            return self.index2word[idx]
        else:
            return self.index2word[UNK_token]
            
    def add_word(self, word):
        if word in self.word2index:
            self.word2count[word] += 1
            
        else:
            self.word2index[word] = self.num_words
            self.index2word[self.num_words] = word
            self.word2count[word] = 1
            self.num_words += 1
            
    def build_vocab(self):        
        for seq in self.digit_seqs:
            for word in seq.split(" "):
                self.add_word(word)

        print("Vocabulary created with %d tokens ..." % self.num_words)
        # return self.num_tokens
    
    def vocab_size(self):
        return self.num_words
    
    def vocabulary(self):
        for idx in self.index2word:
            print(idx, self.index2word[idx])
    
    def encode(self, seq):
        return [self.word2idx(word) for word in seq.split(" ")]
    
    def decode(self, seq):
        return " ".join([self.idx2word(idx) for idx in seq])
    
# Create the vocabulary
with open('../data/ASR/MT_Labels.txt', 'r') as f:
    mt_labels = f.read().splitlines()
mt_labels = [mt_label[:-1] for mt_label in mt_labels]

print("Number of MT sentences : ", len(mt_labels))
vocab_mt = MT_Vocab(mt_labels)
vocab_mt.build_vocab()

# Test the vocabulary
print("\nOriginal sequence : ", mt_labels[4])
encoded_seq = vocab_mt.encode(mt_labels[4])
decoded_seq = vocab_mt.decode(encoded_seq)

print("Encoded sequence  : ", encoded_seq)
print("Decoded sequence  : ", decoded_seq)
# Out:
# Number of MT sentences :  8398
# Vocabulary created with 15 tokens ...
#
# Original sequence :  நான்கு ஒன்பது பூஜ்யம் ஒன்பது மூன்று பூஜ்யம் இரண்டு
# Encoded sequence  :  [10, 7, 11, 7, 9, 11, 4]
# Decoded sequence  :  நான்கு ஒன்பது பூஜ்யம் ஒன்பது மூன்று பூஜ்யம் இரண்டு

# %%
### Define the device

USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# NVIDIA GeForce RTX 2070 Super with Max-Q Design

# %%
# Prepare the data and create the dataloader
max_len = max([len(asr_label) for asr_label in asr_labels]) + 2

X = []
for i in range(len(asr_labels)):
    encoded_seq = [SOS_token] + vocab_asr.encode(asr_labels[i]) + [EOS_token]
    encoded_seq = encoded_seq + [PAD_token] * (max_len - len(encoded_seq))
    
    # Convert to one-hot encoding
    one_hot_enc = np.zeros((max_len, vocab_asr.vocab_size()))
    for j in range(len(encoded_seq)):
        # print(j, encoded_seq[j], vocab_mt.decode([encoded_seq[j]]))
        one_hot_enc[j][encoded_seq[j]] = 1
    
    X.append(one_hot_enc)

Y, Z = [], []
for i in range(len(mt_labels)):
    encoded_seq = [SOS_token] + vocab_mt.encode(mt_labels[i]) + [EOS_token]
    Y.append(encoded_seq + [PAD_token] * (max_len - len(encoded_seq)))
    
    # Convert to one-hot encoding
    one_hot_enc = np.zeros((max_len, vocab_mt.vocab_size()))
    for j in range(len(encoded_seq)):
        # print(j, encoded_seq[j], vocab_mt.decode([encoded_seq[j]]))
        one_hot_enc[j][encoded_seq[j]] = 1
        
    Z.append(one_hot_enc)

X = np.array(X)
Z = np.array(Z)
X = torch.tensor(X, dtype=torch.float)
Y = torch.tensor(Y, dtype=torch.long)
Z = torch.tensor(Z, dtype=torch.float)

print(X.shape, Y.shape, Z.shape)
# Out:
# torch.Size([8398, 9, 15]) torch.Size([8398, 9]) torch.Size([8398, 9, 15])

# %%
# Create the dataloader

class DigitsDataset(Dataset):
    def __init__(self, X, Y, Z):
        super(DigitsDataset, self).__init__()
        self.X = X
        self.Y = Y
        self.Z = Z
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx], self.Z[idx]
    
dataset = DigitsDataset(X, Y, Z)

# %%
# Define the seq2seq model
input_size  = vocab_asr.vocab_size()
hidden_size = 300
output_size = vocab_mt.vocab_size()

n_epochs = 300
batch_size = 512

# %%
# Define the encoder
# Encoder inputs : One-hot encoded ASR labels (B X L X U)

class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, n_layers=2):
        super(EncoderRNN, self).__init__()
        self.input_size = input_size                    # U
        self.hidden_size = hidden_size                  # H
        self.n_layers = n_layers                        
        
        self.U = nn.Linear(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, batch_first=True)
        
    def _init_hidden(self, batch_size):
        return torch.zeros(self.n_layers, batch_size, self.hidden_size).to(device)
    
    # Train the encoder with the decoder
    def forward(self, input, hidden=None):
        hidden = self._init_hidden(input.size(0)) if hidden is None else hidden
                                                        # 2 x B x H
        input = F.relu(self.U(input))                   # B x L x H
        outputs, hidden = self.gru(input, hidden)       # B x L x H, 2 x B x H
        
        hidden = hidden[-1].unsqueeze(0)                # 1 x B x H
        outputs = outputs[:, -1, :].unsqueeze(1)        # B x 1 x H
        
        return outputs, hidden                          # B x L x H, 1 x B x H                        
    
    # Encoder in inference mode
    def inference(self, input):
        hidden = self._init_hidden(input.size(0))
        input = F.relu(self.U(input))
        outputs, hidden = self.gru(input, hidden)
        
        hidden = hidden[-1].unsqueeze(0)
        outputs = outputs[:, -1, :].unsqueeze(1)
        
        return outputs, hidden

# %%
# Define the encoder-decoder attention model

class Attention(nn.Module):
    def __init__(self, hidden_size):
        super(Attention, self).__init__()
        self.hidden_size = hidden_size
        
        self.W1 = nn.Linear(hidden_size, hidden_size)
        self.W2 = nn.Linear(hidden_size, hidden_size)
        self.V  = nn.Linear(hidden_size, 1)
        
    def attend(self, hidden, encoder_states):
        # hidden : 1 x B x H
        # encoder_outputs : B x L x H
        
        hidden = hidden.squeeze(0)                      # B x H
        hidden = hidden.unsqueeze(1)                    # B x 1 x H
        
        # Calculate the attention weights
        attn_weights = self.V(torch.tanh(self.W1(hidden) + self.W2(encoder_states)))
        attn_weights = F.softmax(attn_weights, dim=1)   # B x L x 1
        
        return attn_weights

# %%
# Define the decoder
# Decoder inputs : Encoder outputs (B x L x H)

class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size                  # H
        self.output_size = output_size                  # V
        
        self.U = nn.Linear(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, 1, batch_first=True)
        self.V = nn.Linear(hidden_size, output_size)
        self.attn = Attention(hidden_size)
    
    # Decoder in training mode  
    def forward(self, input, last_hidden, encoder_states):  
        input = F.relu(self.U(input))                               # B x 1 x H        
        atn_weights = self.attn.attend(last_hidden, encoder_states) # B x L x 1
        context = atn_weights * encoder_states                      # B x L x 1 * B x L x H = B x L x H
        
        gru_input = torch.cat((input, context), dim=1)              # B x (L+1) x H
        gru_input = torch.sum(gru_input, dim=1).unsqueeze(1)        # B x 1 x H
        
        output, hidden = self.gru(gru_input, last_hidden)           # B x 1 x H, B x 1 x H        
        output = self.V(output)                                     # B x 1 x V
        
        return output, hidden
    
    # Decoder in inference mode
    def inference(self, input, last_hidden, encoder_states):
        input = F.relu(self.U(input))                               # 1 x 1 x H         
        atn_weights = self.attn.attend(last_hidden, encoder_states) # 1 x L x 1
        context = atn_weights * encoder_states                      # 1 x L x 1 * 1 x L x H = 1 x L x H
        
        gru_input = torch.cat((input, context), dim=1)              # B x (L+1) x H
        gru_input = torch.sum(gru_input, dim=1).unsqueeze(1)        # B x 1 x H
        
        output, hidden = self.gru(gru_input, last_hidden)           # 1 x 1 x H, 1 x 1 x H
        output = self.V(output)                                     # 1 x 1 x V
        labels = F.softmax(output, dim=2)                           # 1 x 1 x V
        
        return output, labels, hidden

# %%
# Define the se2seq model
class Seq2Seq(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=2):
        super(Seq2Seq, self).__init__()
        self.encoder = EncoderRNN(input_size, hidden_size, n_layers)
        self.decoder = DecoderRNN(hidden_size, output_size)
        
    def forward(self, inputs, targets, teacher_forcing_ratio=0.5):
        batch_size = inputs.size(0)
        vocab_size = self.decoder.output_size
        
        encoder_states, hidden = self.encoder(inputs)
        
        target_len = targets.size(1)
        outputs = torch.zeros(batch_size, target_len, vocab_size).to(device)
        decoder_input = torch.zeros(batch_size, 1, vocab_size).to(device)
        decoder_input[:, 0, SOS_token] = 1
        
        use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False
        
        if use_teacher_forcing:
            for t in range(target_len):
                output, hidden = self.decoder(decoder_input, hidden, encoder_states)
                outputs[:, t, :] = output.squeeze(1)
                decoder_input = targets[:, t, :].unsqueeze(1)
        else:
            for t in range(target_len):
                output, hidden = self.decoder(decoder_input, hidden, encoder_states)
                outputs[:, t, :] = output.squeeze(1)
                topv, topi = output.topk(1)
                
                decoder_input = torch.zeros(batch_size, 1, vocab_size).to(device)
                decoder_input[:, 0, topi] = 1
        
        return outputs
    
    def predict(self, input):
        batch_size = input.size(0)
        target_len = input.size(1)
        vocab_size = self.decoder.output_size
        
        outputs = torch.zeros(batch_size, target_len, vocab_size).to(device)
        encoder_states, hidden = self.encoder(input)
        
        decoder_input = torch.zeros(batch_size, 1, vocab_size).to(device)
        decoder_input[:, 0, SOS_token] = 1
        
        for t in range(target_len - 1):
            output, labels, hidden = self.decoder.inference(decoder_input, hidden, encoder_states)
            outputs[:, t, :] = labels.squeeze(1)
            topv, topi = labels.topk(1)
            decoder_input = torch.zeros(batch_size, 1, vocab_size).to(device)
            decoder_input[:, 0, topi] = 1
        
        # Add the EOS token
        outputs[:, target_len - 1, EOS_token] = 1
        
        return outputs

# %%
# Instantiate the model
seq2seq = Seq2Seq(input_size, hidden_size, output_size).to(device)

print(seq2seq.parameters)
# Out:
# <bound method Module.parameters of Seq2Seq(
#   (encoder): EncoderRNN(
#     (U): Linear(in_features=15, out_features=300, bias=True)
#     (gru): GRU(300, 300, num_layers=2, batch_first=True)
#   )
#   (decoder): DecoderRNN(
#     (U): Linear(in_features=15, out_features=300, bias=True)
#     (gru): GRU(300, 300, batch_first=True)
#     (V): Linear(in_features=300, out_features=15, bias=True)
#     (attn): Attention(
#       (W1): Linear(in_features=300, out_features=300, bias=True)
#       (W2): Linear(in_features=300, out_features=300, bias=True)
#       (V): Linear(in_features=300, out_features=1, bias=True)
#     )
#   )
# )>

# %%
# Define the optimizer and loss function
learning_rate = 0.001

seq2seq_optimizer = optim.Adam(seq2seq.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

# %%
# Train the model
seq2seq.train()
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

print("Training started ...")
for epoch in range(n_epochs):
    for i, data in enumerate(dataloader):
        inputs, labels, targets = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        targets = targets.to(device)
        
        if inputs.size(0) != batch_size:
            continue
        
        # Zero the gradients
        seq2seq_optimizer.zero_grad()
        
        # Forward pass
        outputs = seq2seq(inputs, targets)
        
        loss = 0
        for j in range(outputs.size(1)):
            loss += criterion(outputs[:, j, :], labels[:, j])
        
        # Backward pass
        loss.backward()
        seq2seq_optimizer.step()
        
        print("Epoch: {}/{}, Step: {}/{}, Loss: {}".format(epoch+1, n_epochs, i+1, len(dataloader), np.round(loss.item()/max_len, 4)))

print("Training completed !!!")
# Out:
# Training started ...
# Epoch: 1/300, Step: 1/17, Loss: 2.6774
# Epoch: 1/300, Step: 2/17, Loss: 2.5516
# Epoch: 1/300, Step: 3/17, Loss: 2.4262
# Epoch: 1/300, Step: 4/17, Loss: 2.3362
# Epoch: 1/300, Step: 5/17, Loss: 2.2657
# Epoch: 1/300, Step: 6/17, Loss: 2.1533
# Epoch: 1/300, Step: 7/17, Loss: 2.1022
# Epoch: 1/300, Step: 8/17, Loss: 1.9719
# Epoch: 1/300, Step: 9/17, Loss: 1.9332
# Epoch: 1/300, Step: 10/17, Loss: 1.8644
# Epoch: 1/300, Step: 11/17, Loss: 1.8543
# Epoch: 1/300, Step: 12/17, Loss: 1.7908
# Epoch: 1/300, Step: 13/17, Loss: 1.8083
# Epoch: 1/300, Step: 14/17, Loss: 1.7511
# Epoch: 1/300, Step: 15/17, Loss: 1.7459
# Epoch: 1/300, Step: 16/17, Loss: 1.6838
# Epoch: 2/300, Step: 1/17, Loss: 1.6398
# Epoch: 2/300, Step: 2/17, Loss: 1.6264
# Epoch: 2/300, Step: 3/17, Loss: 1.5482
# Epoch: 2/300, Step: 4/17, Loss: 1.548
# Epoch: 2/300, Step: 5/17, Loss: 1.5442
# Epoch: 2/300, Step: 6/17, Loss: 1.6128
# Epoch: 2/300, Step: 7/17, Loss: 1.5054
# Epoch: 2/300, Step: 8/17, Loss: 1.5421
# Epoch: 2/300, Step: 9/17, Loss: 1.5633
# Epoch: 2/300, Step: 10/17, Loss: 1.4507
# Epoch: 2/300, Step: 11/17, Loss: 1.4759
# Epoch: 2/300, Step: 12/17, Loss: 1.4869
# Epoch: 2/300, Step: 13/17, Loss: 1.3936
# Epoch: 2/300, Step: 14/17, Loss: 1.47
# Epoch: 2/300, Step: 15/17, Loss: 1.4199
# Epoch: 2/300, Step: 16/17, Loss: 1.4256
# Epoch: 3/300, Step: 1/17, Loss: 1.4599
# Epoch: 3/300, Step: 2/17, Loss: 1.3971
# Epoch: 3/300, Step: 3/17, Loss: 1.4333
# Epoch: 3/300, Step: 4/17, Loss: 1.37
# Epoch: 3/300, Step: 5/17, Loss: 1.4169
# Epoch: 3/300, Step: 6/17, Loss: 1.3794
# Epoch: 3/300, Step: 7/17, Loss: 1.375
# Epoch: 3/300, Step: 8/17, Loss: 1.3994
# Epoch: 3/300, Step: 9/17, Loss: 1.3364
# Epoch: 3/300, Step: 10/17, Loss: 1.3833
# Epoch: 3/300, Step: 11/17, Loss: 1.3206
# Epoch: 3/300, Step: 12/17, Loss: 1.3794
# Epoch: 3/300, Step: 13/17, Loss: 1.371
# Epoch: 3/300, Step: 14/17, Loss: 1.3427
# Epoch: 3/300, Step: 15/17, Loss: 1.3015
# Epoch: 3/300, Step: 16/17, Loss: 1.3207
# Epoch: 4/300, Step: 1/17, Loss: 1.3284
# Epoch: 4/300, Step: 2/17, Loss: 1.293
# Epoch: 4/300, Step: 3/17, Loss: 1.3014
# Epoch: 4/300, Step: 4/17, Loss: 1.3061
# Epoch: 4/300, Step: 5/17, Loss: 1.3095
# Epoch: 4/300, Step: 6/17, Loss: 1.314
# Epoch: 4/300, Step: 7/17, Loss: 1.311
# Epoch: 4/300, Step: 8/17, Loss: 1.2906
# Epoch: 4/300, Step: 9/17, Loss: 1.3071
# Epoch: 4/300, Step: 10/17, Loss: 1.2779
# Epoch: 4/300, Step: 11/17, Loss: 1.283
# Epoch: 4/300, Step: 12/17, Loss: 1.2944
# Epoch: 4/300, Step: 13/17, Loss: 1.2822
# Epoch: 4/300, Step: 14/17, Loss: 1.3086
# Epoch: 4/300, Step: 15/17, Loss: 1.2784
# Epoch: 4/300, Step: 16/17, Loss: 1.3065
# Epoch: 5/300, Step: 1/17, Loss: 1.2497
# Epoch: 5/300, Step: 2/17, Loss: 1.2708
# Epoch: 5/300, Step: 3/17, Loss: 1.2889
# Epoch: 5/300, Step: 4/17, Loss: 1.2967
# Epoch: 5/300, Step: 5/17, Loss: 1.2747
# Epoch: 5/300, Step: 6/17, Loss: 1.2471
# Epoch: 5/300, Step: 7/17, Loss: 1.28
# Epoch: 5/300, Step: 8/17, Loss: 1.2708
# Epoch: 5/300, Step: 9/17, Loss: 1.2949
# Epoch: 5/300, Step: 10/17, Loss: 1.2911
# Epoch: 5/300, Step: 11/17, Loss: 1.3
# Epoch: 5/300, Step: 12/17, Loss: 1.2599
# Epoch: 5/300, Step: 13/17, Loss: 1.2831
# Epoch: 5/300, Step: 14/17, Loss: 1.2719
# Epoch: 5/300, Step: 15/17, Loss: 1.2894
# Epoch: 5/300, Step: 16/17, Loss: 1.2735
# Epoch: 6/300, Step: 1/17, Loss: 1.2674
# Epoch: 6/300, Step: 2/17, Loss: 1.2556
# Epoch: 6/300, Step: 3/17, Loss: 1.2843
# Epoch: 6/300, Step: 4/17, Loss: 1.2545
# Epoch: 6/300, Step: 5/17, Loss: 1.3046
# Epoch: 6/300, Step: 6/17, Loss: 1.2605
# Epoch: 6/300, Step: 7/17, Loss: 1.2891
# Epoch: 6/300, Step: 8/17, Loss: 1.2683
# Epoch: 6/300, Step: 9/17, Loss: 1.2405
# Epoch: 6/300, Step: 10/17, Loss: 1.2831
# Epoch: 6/300, Step: 11/17, Loss: 1.2411
# Epoch: 6/300, Step: 12/17, Loss: 1.2666
# Epoch: 6/300, Step: 13/17, Loss: 1.2638
# Epoch: 6/300, Step: 14/17, Loss: 1.2894
# Epoch: 6/300, Step: 15/17, Loss: 1.2842
# Epoch: 6/300, Step: 16/17, Loss: 1.2833
# Epoch: 7/300, Step: 1/17, Loss: 1.2941
# Epoch: 7/300, Step: 2/17, Loss: 1.2661
# Epoch: 7/300, Step: 3/17, Loss: 1.2625
# Epoch: 7/300, Step: 4/17, Loss: 1.2373
# Epoch: 7/300, Step: 5/17, Loss: 1.2691
# Epoch: 7/300, Step: 6/17, Loss: 1.244
# Epoch: 7/300, Step: 7/17, Loss: 1.2806
# Epoch: 7/300, Step: 8/17, Loss: 1.2959
# Epoch: 7/300, Step: 9/17, Loss: 1.282
# Epoch: 7/300, Step: 10/17, Loss: 1.2611
# Epoch: 7/300, Step: 11/17, Loss: 1.2581
# Epoch: 7/300, Step: 12/17, Loss: 1.2768
# Epoch: 7/300, Step: 13/17, Loss: 1.2781
# Epoch: 7/300, Step: 14/17, Loss: 1.2763
# Epoch: 7/300, Step: 15/17, Loss: 1.2434
# Epoch: 7/300, Step: 16/17, Loss: 1.27
# Epoch: 8/300, Step: 1/17, Loss: 1.2615
# Epoch: 8/300, Step: 2/17, Loss: 1.2653
# Epoch: 8/300, Step: 3/17, Loss: 1.2485
# Epoch: 8/300, Step: 4/17, Loss: 1.2945
# Epoch: 8/300, Step: 5/17, Loss: 1.2637
# Epoch: 8/300, Step: 6/17, Loss: 1.2792
# Epoch: 8/300, Step: 7/17, Loss: 1.2492
# Epoch: 8/300, Step: 8/17, Loss: 1.2458
# Epoch: 8/300, Step: 9/17, Loss: 1.2734
# Epoch: 8/300, Step: 10/17, Loss: 1.2662
# Epoch: 8/300, Step: 11/17, Loss: 1.2815
# Epoch: 8/300, Step: 12/17, Loss: 1.2911
# Epoch: 8/300, Step: 13/17, Loss: 1.256
# Epoch: 8/300, Step: 14/17, Loss: 1.2826
# Epoch: 8/300, Step: 15/17, Loss: 1.2594
# Epoch: 8/300, Step: 16/17, Loss: 1.2689
# Epoch: 9/300, Step: 1/17, Loss: 1.2937
# Epoch: 9/300, Step: 2/17, Loss: 1.2441
# Epoch: 9/300, Step: 3/17, Loss: 1.2754
# Epoch: 9/300, Step: 4/17, Loss: 1.2597
# Epoch: 9/300, Step: 5/17, Loss: 1.2655
# Epoch: 9/300, Step: 6/17, Loss: 1.2971
# Epoch: 9/300, Step: 7/17, Loss: 1.2626
# Epoch: 9/300, Step: 8/17, Loss: 1.2452
# Epoch: 9/300, Step: 9/17, Loss: 1.2636
# Epoch: 9/300, Step: 10/17, Loss: 1.2584
# Epoch: 9/300, Step: 11/17, Loss: 1.2421
# Epoch: 9/300, Step: 12/17, Loss: 1.2537
# Epoch: 9/300, Step: 13/17, Loss: 1.2607
# Epoch: 9/300, Step: 14/17, Loss: 1.2633
# Epoch: 9/300, Step: 15/17, Loss: 1.2595
# Epoch: 9/300, Step: 16/17, Loss: 1.2694
# Epoch: 10/300, Step: 1/17, Loss: 1.2421
# Epoch: 10/300, Step: 2/17, Loss: 1.2423
# Epoch: 10/300, Step: 3/17, Loss: 1.2543
# Epoch: 10/300, Step: 4/17, Loss: 1.2772
# Epoch: 10/300, Step: 5/17, Loss: 1.2468
# Epoch: 10/300, Step: 6/17, Loss: 1.2615
# Epoch: 10/300, Step: 7/17, Loss: 1.2722
# Epoch: 10/300, Step: 8/17, Loss: 1.2691
# Epoch: 10/300, Step: 9/17, Loss: 1.2813
# Epoch: 10/300, Step: 10/17, Loss: 1.2503
# Epoch: 10/300, Step: 11/17, Loss: 1.232
# Epoch: 10/300, Step: 12/17, Loss: 1.2248
# Epoch: 10/300, Step: 13/17, Loss: 1.2553
# Epoch: 10/300, Step: 14/17, Loss: 1.2324
# Epoch: 10/300, Step: 15/17, Loss: 1.2188
# Epoch: 10/300, Step: 16/17, Loss: 1.2719
# Epoch: 11/300, Step: 1/17, Loss: 1.2367
# Epoch: 11/300, Step: 2/17, Loss: 1.2235
# Epoch: 11/300, Step: 3/17, Loss: 1.2393
# Epoch: 11/300, Step: 4/17, Loss: 1.2233
# Epoch: 11/300, Step: 5/17, Loss: 1.2354
# Epoch: 11/300, Step: 6/17, Loss: 1.2179
# Epoch: 11/300, Step: 7/17, Loss: 1.2548
# Epoch: 11/300, Step: 8/17, Loss: 1.2035
# Epoch: 11/300, Step: 9/17, Loss: 1.1773
# Epoch: 11/300, Step: 10/17, Loss: 1.2001
# Epoch: 11/300, Step: 11/17, Loss: 1.2315
# Epoch: 11/300, Step: 12/17, Loss: 1.212
# Epoch: 11/300, Step: 13/17, Loss: 1.1978
# Epoch: 11/300, Step: 14/17, Loss: 1.1896
# Epoch: 11/300, Step: 15/17, Loss: 1.1971
# Epoch: 11/300, Step: 16/17, Loss: 1.2172
# Epoch: 12/300, Step: 1/17, Loss: 1.1782
# Epoch: 12/300, Step: 2/17, Loss: 1.2098
# Epoch: 12/300, Step: 3/17, Loss: 1.1994
# Epoch: 12/300, Step: 4/17, Loss: 1.1986
# Epoch: 12/300, Step: 5/17, Loss: 1.1669
# Epoch: 12/300, Step: 6/17, Loss: 1.2712
# Epoch: 12/300, Step: 7/17, Loss: 3.6837
# Epoch: 12/300, Step: 8/17, Loss: 2.0683
# Epoch: 12/300, Step: 9/17, Loss: 2.3351
# Epoch: 12/300, Step: 10/17, Loss: 1.2777
# Epoch: 12/300, Step: 11/17, Loss: 1.6927
# Epoch: 12/300, Step: 12/17, Loss: 1.8309
# Epoch: 12/300, Step: 13/17, Loss: 1.9602
# Epoch: 12/300, Step: 14/17, Loss: 1.3722
# Epoch: 12/300, Step: 15/17, Loss: 1.5082
# Epoch: 12/300, Step: 16/17, Loss: 1.6042
# Epoch: 13/300, Step: 1/17, Loss: 1.4234
# Epoch: 13/300, Step: 2/17, Loss: 1.3818
# Epoch: 13/300, Step: 3/17, Loss: 1.5659
# Epoch: 13/300, Step: 4/17, Loss: 1.4278
# Epoch: 13/300, Step: 5/17, Loss: 1.3703
# Epoch: 13/300, Step: 6/17, Loss: 1.3493
# Epoch: 13/300, Step: 7/17, Loss: 1.3528
# Epoch: 13/300, Step: 8/17, Loss: 1.4861
# Epoch: 13/300, Step: 9/17, Loss: 1.3467
# Epoch: 13/300, Step: 10/17, Loss: 1.3056
# Epoch: 13/300, Step: 11/17, Loss: 1.3416
# Epoch: 13/300, Step: 12/17, Loss: 1.2693
# Epoch: 13/300, Step: 13/17, Loss: 1.2624
# Epoch: 13/300, Step: 14/17, Loss: 1.3075
# Epoch: 13/300, Step: 15/17, Loss: 1.2393
# Epoch: 13/300, Step: 16/17, Loss: 1.2546
# Epoch: 14/300, Step: 1/17, Loss: 1.268
# Epoch: 14/300, Step: 2/17, Loss: 1.239
# Epoch: 14/300, Step: 3/17, Loss: 1.1787
# Epoch: 14/300, Step: 4/17, Loss: 1.223
# Epoch: 14/300, Step: 5/17, Loss: 1.2218
# Epoch: 14/300, Step: 6/17, Loss: 1.1877
# Epoch: 14/300, Step: 7/17, Loss: 1.1786
# Epoch: 14/300, Step: 8/17, Loss: 1.1718
# Epoch: 14/300, Step: 9/17, Loss: 1.1659
# Epoch: 14/300, Step: 10/17, Loss: 1.163
# Epoch: 14/300, Step: 11/17, Loss: 1.2497
# Epoch: 14/300, Step: 12/17, Loss: 1.1505
# Epoch: 14/300, Step: 13/17, Loss: 1.1603
# Epoch: 14/300, Step: 14/17, Loss: 1.192
# Epoch: 14/300, Step: 15/17, Loss: 1.1745
# Epoch: 14/300, Step: 16/17, Loss: 1.1466
# Epoch: 15/300, Step: 1/17, Loss: 1.1345
# Epoch: 15/300, Step: 2/17, Loss: 1.1699
# Epoch: 15/300, Step: 3/17, Loss: 1.104
# Epoch: 15/300, Step: 4/17, Loss: 1.1304
# Epoch: 15/300, Step: 5/17, Loss: 1.1241
# Epoch: 15/300, Step: 6/17, Loss: 1.1436
# Epoch: 15/300, Step: 7/17, Loss: 1.0986
# Epoch: 15/300, Step: 8/17, Loss: 1.0993
# Epoch: 15/300, Step: 9/17, Loss: 1.0939
# Epoch: 15/300, Step: 10/17, Loss: 1.1231
# Epoch: 15/300, Step: 11/17, Loss: 1.1096
# Epoch: 15/300, Step: 12/17, Loss: 1.0963
# Epoch: 15/300, Step: 13/17, Loss: 1.0795
# Epoch: 15/300, Step: 14/17, Loss: 1.1216
# Epoch: 15/300, Step: 15/17, Loss: 1.1003
# Epoch: 15/300, Step: 16/17, Loss: 1.0787
# Epoch: 16/300, Step: 1/17, Loss: 1.0797
# Epoch: 16/300, Step: 2/17, Loss: 1.0558
# Epoch: 16/300, Step: 3/17, Loss: 1.0672
# Epoch: 16/300, Step: 4/17, Loss: 1.093
# Epoch: 16/300, Step: 5/17, Loss: 1.0609
# Epoch: 16/300, Step: 6/17, Loss: 1.1186
# Epoch: 16/300, Step: 7/17, Loss: 1.0246
# Epoch: 16/300, Step: 8/17, Loss: 1.0652
# Epoch: 16/300, Step: 9/17, Loss: 1.0345
# Epoch: 16/300, Step: 10/17, Loss: 1.0397
# Epoch: 16/300, Step: 11/17, Loss: 1.0511
# Epoch: 16/300, Step: 12/17, Loss: 1.0408
# Epoch: 16/300, Step: 13/17, Loss: 1.0378
# Epoch: 16/300, Step: 14/17, Loss: 1.0443
# Epoch: 16/300, Step: 15/17, Loss: 0.9968
# Epoch: 16/300, Step: 16/17, Loss: 1.0352
# Epoch: 17/300, Step: 1/17, Loss: 1.0163
# Epoch: 17/300, Step: 2/17, Loss: 1.0028
# Epoch: 17/300, Step: 3/17, Loss: 1.031
# Epoch: 17/300, Step: 4/17, Loss: 1.0251
# Epoch: 17/300, Step: 5/17, Loss: 1.0169
# Epoch: 17/300, Step: 6/17, Loss: 0.9984
# Epoch: 17/300, Step: 7/17, Loss: 1.0087
# Epoch: 17/300, Step: 8/17, Loss: 1.0
# Epoch: 17/300, Step: 9/17, Loss: 0.9362
# Epoch: 17/300, Step: 10/17, Loss: 0.9756
# Epoch: 17/300, Step: 11/17, Loss: 0.98
# Epoch: 17/300, Step: 12/17, Loss: 0.9925
# Epoch: 17/300, Step: 13/17, Loss: 0.9812
# Epoch: 17/300, Step: 14/17, Loss: 0.9553
# Epoch: 17/300, Step: 15/17, Loss: 0.9648
# Epoch: 17/300, Step: 16/17, Loss: 0.9521
# Epoch: 18/300, Step: 1/17, Loss: 0.9504
# Epoch: 18/300, Step: 2/17, Loss: 0.9514
# Epoch: 18/300, Step: 3/17, Loss: 0.9418
# Epoch: 18/300, Step: 4/17, Loss: 0.9678
# Epoch: 18/300, Step: 5/17, Loss: 0.9504
# Epoch: 18/300, Step: 6/17, Loss: 0.914
# Epoch: 18/300, Step: 7/17, Loss: 0.935
# Epoch: 18/300, Step: 8/17, Loss: 0.9139
# Epoch: 18/300, Step: 9/17, Loss: 0.9435
# Epoch: 18/300, Step: 10/17, Loss: 0.9153
# Epoch: 18/300, Step: 11/17, Loss: 0.8928
# Epoch: 18/300, Step: 12/17, Loss: 0.8876
# Epoch: 18/300, Step: 13/17, Loss: 0.9368
# Epoch: 18/300, Step: 14/17, Loss: 0.8848
# Epoch: 18/300, Step: 15/17, Loss: 0.8929
# Epoch: 18/300, Step: 16/17, Loss: 0.8947
# Epoch: 19/300, Step: 1/17, Loss: 0.873
# Epoch: 19/300, Step: 2/17, Loss: 0.8751
# Epoch: 19/300, Step: 3/17, Loss: 0.8843
# Epoch: 19/300, Step: 4/17, Loss: 0.8867
# Epoch: 19/300, Step: 5/17, Loss: 0.8505
# Epoch: 19/300, Step: 6/17, Loss: 0.8616
# Epoch: 19/300, Step: 7/17, Loss: 0.8409
# Epoch: 19/300, Step: 8/17, Loss: 0.8425
# Epoch: 19/300, Step: 9/17, Loss: 0.8516
# Epoch: 19/300, Step: 10/17, Loss: 0.8596
# Epoch: 19/300, Step: 11/17, Loss: 0.8195
# Epoch: 19/300, Step: 12/17, Loss: 0.8666
# Epoch: 19/300, Step: 13/17, Loss: 0.8083
# Epoch: 19/300, Step: 14/17, Loss: 0.8328
# Epoch: 19/300, Step: 15/17, Loss: 0.8177
# Epoch: 19/300, Step: 16/17, Loss: 0.7865
# Epoch: 20/300, Step: 1/17, Loss: 0.7908
# Epoch: 20/300, Step: 2/17, Loss: 0.768
# Epoch: 20/300, Step: 3/17, Loss: 0.7895
# Epoch: 20/300, Step: 4/17, Loss: 0.7754
# Epoch: 20/300, Step: 5/17, Loss: 0.7935
# Epoch: 20/300, Step: 6/17, Loss: 0.7932
# Epoch: 20/300, Step: 7/17, Loss: 0.8025
# Epoch: 20/300, Step: 8/17, Loss: 0.771
# Epoch: 20/300, Step: 9/17, Loss: 0.7732
# Epoch: 20/300, Step: 10/17, Loss: 0.7579
# Epoch: 20/300, Step: 11/17, Loss: 0.7593
# Epoch: 20/300, Step: 12/17, Loss: 0.7648
# Epoch: 20/300, Step: 13/17, Loss: 0.7722
# Epoch: 20/300, Step: 14/17, Loss: 0.76
# Epoch: 20/300, Step: 15/17, Loss: 0.7818
# Epoch: 20/300, Step: 16/17, Loss: 0.7348
# Epoch: 21/300, Step: 1/17, Loss: 0.7348
# Epoch: 21/300, Step: 2/17, Loss: 0.7379
# Epoch: 21/300, Step: 3/17, Loss: 0.7675
# Epoch: 21/300, Step: 4/17, Loss: 0.7038
# Epoch: 21/300, Step: 5/17, Loss: 0.6831
# Epoch: 21/300, Step: 6/17, Loss: 0.743
# Epoch: 21/300, Step: 7/17, Loss: 0.6957
# Epoch: 21/300, Step: 8/17, Loss: 0.7229
# Epoch: 21/300, Step: 9/17, Loss: 0.7099
# Epoch: 21/300, Step: 10/17, Loss: 0.6704
# Epoch: 21/300, Step: 11/17, Loss: 0.6659
# Epoch: 21/300, Step: 12/17, Loss: 0.6835
# Epoch: 21/300, Step: 13/17, Loss: 0.6949
# Epoch: 21/300, Step: 14/17, Loss: 0.694
# Epoch: 21/300, Step: 15/17, Loss: 0.6665
# Epoch: 21/300, Step: 16/17, Loss: 0.6585
# Epoch: 22/300, Step: 1/17, Loss: 0.6378
# Epoch: 22/300, Step: 2/17, Loss: 0.6391
# Epoch: 22/300, Step: 3/17, Loss: 0.6606
# Epoch: 22/300, Step: 4/17, Loss: 0.6644
# Epoch: 22/300, Step: 5/17, Loss: 0.6474
# Epoch: 22/300, Step: 6/17, Loss: 0.6472
# Epoch: 22/300, Step: 7/17, Loss: 0.6623
# Epoch: 22/300, Step: 8/17, Loss: 0.6192
# Epoch: 22/300, Step: 9/17, Loss: 0.6406
# Epoch: 22/300, Step: 10/17, Loss: 0.6621
# Epoch: 22/300, Step: 11/17, Loss: 0.6225
# Epoch: 22/300, Step: 12/17, Loss: 0.6343
# Epoch: 22/300, Step: 13/17, Loss: 0.6591
# Epoch: 22/300, Step: 14/17, Loss: 0.6366
# Epoch: 22/300, Step: 15/17, Loss: 0.6386
# Epoch: 22/300, Step: 16/17, Loss: 0.5854
# Epoch: 23/300, Step: 1/17, Loss: 0.5924
# Epoch: 23/300, Step: 2/17, Loss: 0.6222
# Epoch: 23/300, Step: 3/17, Loss: 0.6004
# Epoch: 23/300, Step: 4/17, Loss: 0.6169
# Epoch: 23/300, Step: 5/17, Loss: 0.595
# Epoch: 23/300, Step: 6/17, Loss: 0.5814
# Epoch: 23/300, Step: 7/17, Loss: 0.6027
# Epoch: 23/300, Step: 8/17, Loss: 0.5522
# Epoch: 23/300, Step: 9/17, Loss: 0.5397
# Epoch: 23/300, Step: 10/17, Loss: 0.5617
# Epoch: 23/300, Step: 11/17, Loss: 0.5381
# Epoch: 23/300, Step: 12/17, Loss: 0.5303
# Epoch: 23/300, Step: 13/17, Loss: 0.6021
# Epoch: 23/300, Step: 14/17, Loss: 0.5873
# Epoch: 23/300, Step: 15/17, Loss: 0.5995
# Epoch: 23/300, Step: 16/17, Loss: 0.5663
# Epoch: 24/300, Step: 1/17, Loss: 0.533
# Epoch: 24/300, Step: 2/17, Loss: 0.5178
# Epoch: 24/300, Step: 3/17, Loss: 0.5776
# Epoch: 24/300, Step: 4/17, Loss: 0.5407
# Epoch: 24/300, Step: 5/17, Loss: 0.5666
# Epoch: 24/300, Step: 6/17, Loss: 0.5141
# Epoch: 24/300, Step: 7/17, Loss: 0.4765
# Epoch: 24/300, Step: 8/17, Loss: 0.5737
# Epoch: 24/300, Step: 9/17, Loss: 0.4948
# Epoch: 24/300, Step: 10/17, Loss: 0.4732
# Epoch: 24/300, Step: 11/17, Loss: 0.4913
# Epoch: 24/300, Step: 12/17, Loss: 0.4815
# Epoch: 24/300, Step: 13/17, Loss: 0.5339
# Epoch: 24/300, Step: 14/17, Loss: 0.4544
# Epoch: 24/300, Step: 15/17, Loss: 0.5303
# Epoch: 24/300, Step: 16/17, Loss: 0.4745
# Epoch: 25/300, Step: 1/17, Loss: 0.4417
# Epoch: 25/300, Step: 2/17, Loss: 0.5228
# Epoch: 25/300, Step: 3/17, Loss: 0.5248
# Epoch: 25/300, Step: 4/17, Loss: 0.5093
# Epoch: 25/300, Step: 5/17, Loss: 0.4979
# Epoch: 25/300, Step: 6/17, Loss: 0.4371
# Epoch: 25/300, Step: 7/17, Loss: 0.5045
# Epoch: 25/300, Step: 8/17, Loss: 0.5015
# Epoch: 25/300, Step: 9/17, Loss: 0.5181
# Epoch: 25/300, Step: 10/17, Loss: 0.4898
# Epoch: 25/300, Step: 11/17, Loss: 0.4641
# Epoch: 25/300, Step: 12/17, Loss: 0.4301
# Epoch: 25/300, Step: 13/17, Loss: 0.5176
# Epoch: 25/300, Step: 14/17, Loss: 0.4842
# Epoch: 25/300, Step: 15/17, Loss: 0.4885
# Epoch: 25/300, Step: 16/17, Loss: 0.4789
# Epoch: 26/300, Step: 1/17, Loss: 0.4224
# Epoch: 26/300, Step: 2/17, Loss: 0.458
# Epoch: 26/300, Step: 3/17, Loss: 0.3892
# Epoch: 26/300, Step: 4/17, Loss: 0.4072
# Epoch: 26/300, Step: 5/17, Loss: 0.399
# Epoch: 26/300, Step: 6/17, Loss: 0.3803
# Epoch: 26/300, Step: 7/17, Loss: 0.4762
# Epoch: 26/300, Step: 8/17, Loss: 0.4527
# Epoch: 26/300, Step: 9/17, Loss: 0.4943
# Epoch: 26/300, Step: 10/17, Loss: 0.3813
# Epoch: 26/300, Step: 11/17, Loss: 0.4622
# Epoch: 26/300, Step: 12/17, Loss: 0.3853
# Epoch: 26/300, Step: 13/17, Loss: 0.4423
# Epoch: 26/300, Step: 14/17, Loss: 0.3569
# Epoch: 26/300, Step: 15/17, Loss: 0.4751
# Epoch: 26/300, Step: 16/17, Loss: 0.4484
# Epoch: 27/300, Step: 1/17, Loss: 0.4197
# Epoch: 27/300, Step: 2/17, Loss: 0.368
# Epoch: 27/300, Step: 3/17, Loss: 0.4289
# Epoch: 27/300, Step: 4/17, Loss: 0.4305
# Epoch: 27/300, Step: 5/17, Loss: 0.4254
# Epoch: 27/300, Step: 6/17, Loss: 0.4268
# Epoch: 27/300, Step: 7/17, Loss: 0.3706
# Epoch: 27/300, Step: 8/17, Loss: 0.3554
# Epoch: 27/300, Step: 9/17, Loss: 0.3177
# Epoch: 27/300, Step: 10/17, Loss: 0.4209
# Epoch: 27/300, Step: 11/17, Loss: 0.3483
# Epoch: 27/300, Step: 12/17, Loss: 0.3215
# Epoch: 27/300, Step: 13/17, Loss: 0.4042
# Epoch: 27/300, Step: 14/17, Loss: 0.3283
# Epoch: 27/300, Step: 15/17, Loss: 0.3909
# Epoch: 27/300, Step: 16/17, Loss: 0.3108
# Epoch: 28/300, Step: 1/17, Loss: 0.4003
# Epoch: 28/300, Step: 2/17, Loss: 0.3874
# Epoch: 28/300, Step: 3/17, Loss: 0.399
# Epoch: 28/300, Step: 4/17, Loss: 0.3
# Epoch: 28/300, Step: 5/17, Loss: 0.3208
# Epoch: 28/300, Step: 6/17, Loss: 0.3797
# Epoch: 28/300, Step: 7/17, Loss: 0.3027
# Epoch: 28/300, Step: 8/17, Loss: 0.3971
# Epoch: 28/300, Step: 9/17, Loss: 0.267
# Epoch: 28/300, Step: 10/17, Loss: 0.3953
# Epoch: 28/300, Step: 11/17, Loss: 0.2892
# Epoch: 28/300, Step: 12/17, Loss: 0.3695
# Epoch: 28/300, Step: 13/17, Loss: 0.2667
# Epoch: 28/300, Step: 14/17, Loss: 0.2812
# Epoch: 28/300, Step: 15/17, Loss: 0.3716
# Epoch: 28/300, Step: 16/17, Loss: 0.378
# Epoch: 29/300, Step: 1/17, Loss: 0.3674
# Epoch: 29/300, Step: 2/17, Loss: 0.3401
# Epoch: 29/300, Step: 3/17, Loss: 0.278
# Epoch: 29/300, Step: 4/17, Loss: 0.3563
# Epoch: 29/300, Step: 5/17, Loss: 0.2731
# Epoch: 29/300, Step: 6/17, Loss: 0.3263
# Epoch: 29/300, Step: 7/17, Loss: 0.3357
# Epoch: 29/300, Step: 8/17, Loss: 0.2514
# Epoch: 29/300, Step: 9/17, Loss: 0.2483
# Epoch: 29/300, Step: 10/17, Loss: 0.2583
# Epoch: 29/300, Step: 11/17, Loss: 0.2571
# Epoch: 29/300, Step: 12/17, Loss: 0.2493
# Epoch: 29/300, Step: 13/17, Loss: 0.236
# Epoch: 29/300, Step: 14/17, Loss: 0.3286
# Epoch: 29/300, Step: 15/17, Loss: 0.3285
# Epoch: 29/300, Step: 16/17, Loss: 0.2472
# Epoch: 30/300, Step: 1/17, Loss: 0.3195
# Epoch: 30/300, Step: 2/17, Loss: 0.24
# Epoch: 30/300, Step: 3/17, Loss: 0.3293
# Epoch: 30/300, Step: 4/17, Loss: 0.3214
# Epoch: 30/300, Step: 5/17, Loss: 0.2999
# Epoch: 30/300, Step: 6/17, Loss: 0.2232
# Epoch: 30/300, Step: 7/17, Loss: 0.2207
# Epoch: 30/300, Step: 8/17, Loss: 0.3213
# Epoch: 30/300, Step: 9/17, Loss: 0.2144
# Epoch: 30/300, Step: 10/17, Loss: 0.2907
# Epoch: 30/300, Step: 11/17, Loss: 0.3003
# Epoch: 30/300, Step: 12/17, Loss: 0.2959
# Epoch: 30/300, Step: 13/17, Loss: 0.2213
# Epoch: 30/300, Step: 14/17, Loss: 0.2042
# Epoch: 30/300, Step: 15/17, Loss: 0.303
# Epoch: 30/300, Step: 16/17, Loss: 0.2765
# Epoch: 31/300, Step: 1/17, Loss: 0.2157
# Epoch: 31/300, Step: 2/17, Loss: 0.208
# Epoch: 31/300, Step: 3/17, Loss: 0.1898
# Epoch: 31/300, Step: 4/17, Loss: 0.312
# Epoch: 31/300, Step: 5/17, Loss: 0.2817
# Epoch: 31/300, Step: 6/17, Loss: 0.2082
# Epoch: 31/300, Step: 7/17, Loss: 0.2293
# Epoch: 31/300, Step: 8/17, Loss: 0.1885
# Epoch: 31/300, Step: 9/17, Loss: 0.2148
# Epoch: 31/300, Step: 10/17, Loss: 0.1849
# Epoch: 31/300, Step: 11/17, Loss: 0.2775
# Epoch: 31/300, Step: 12/17, Loss: 0.2895
# Epoch: 31/300, Step: 13/17, Loss: 0.2105
# Epoch: 31/300, Step: 14/17, Loss: 0.1903
# Epoch: 31/300, Step: 15/17, Loss: 0.3093
# Epoch: 31/300, Step: 16/17, Loss: 0.2787
# Epoch: 32/300, Step: 1/17, Loss: 0.1932
# Epoch: 32/300, Step: 2/17, Loss: 0.1878
# Epoch: 32/300, Step: 3/17, Loss: 0.2152
# Epoch: 32/300, Step: 4/17, Loss: 0.1767
# Epoch: 32/300, Step: 5/17, Loss: 0.2716
# Epoch: 32/300, Step: 6/17, Loss: 0.1891
# Epoch: 32/300, Step: 7/17, Loss: 0.2909
# Epoch: 32/300, Step: 8/17, Loss: 0.1795
# Epoch: 32/300, Step: 9/17, Loss: 0.2871
# Epoch: 32/300, Step: 10/17, Loss: 0.1618
# Epoch: 32/300, Step: 11/17, Loss: 0.2677
# Epoch: 32/300, Step: 12/17, Loss: 0.2376
# Epoch: 32/300, Step: 13/17, Loss: 0.1709
# Epoch: 32/300, Step: 14/17, Loss: 0.1673
# Epoch: 32/300, Step: 15/17, Loss: 0.2604
# Epoch: 32/300, Step: 16/17, Loss: 0.2454
# Epoch: 33/300, Step: 1/17, Loss: 0.1687
# Epoch: 33/300, Step: 2/17, Loss: 0.1611
# Epoch: 33/300, Step: 3/17, Loss: 0.2336
# Epoch: 33/300, Step: 4/17, Loss: 0.1639
# Epoch: 33/300, Step: 5/17, Loss: 0.1579
# Epoch: 33/300, Step: 6/17, Loss: 0.2375
# Epoch: 33/300, Step: 7/17, Loss: 0.214
# Epoch: 33/300, Step: 8/17, Loss: 0.2142
# Epoch: 33/300, Step: 9/17, Loss: 0.1647
# Epoch: 33/300, Step: 10/17, Loss: 0.1473
# Epoch: 33/300, Step: 11/17, Loss: 0.2251
# Epoch: 33/300, Step: 12/17, Loss: 0.2173
# Epoch: 33/300, Step: 13/17, Loss: 0.2111
# Epoch: 33/300, Step: 14/17, Loss: 0.1417
# Epoch: 33/300, Step: 15/17, Loss: 0.2197
# Epoch: 33/300, Step: 16/17, Loss: 0.1406
# Epoch: 34/300, Step: 1/17, Loss: 0.124
# Epoch: 34/300, Step: 2/17, Loss: 0.2128
# Epoch: 34/300, Step: 3/17, Loss: 0.1292
# Epoch: 34/300, Step: 4/17, Loss: 0.1329
# Epoch: 34/300, Step: 5/17, Loss: 0.2112
# Epoch: 34/300, Step: 6/17, Loss: 0.1291
# Epoch: 34/300, Step: 7/17, Loss: 0.1291
# Epoch: 34/300, Step: 8/17, Loss: 0.197
# Epoch: 34/300, Step: 9/17, Loss: 0.1837
# Epoch: 34/300, Step: 10/17, Loss: 0.1886
# Epoch: 34/300, Step: 11/17, Loss: 0.1762
# Epoch: 34/300, Step: 12/17, Loss: 0.1193
# Epoch: 34/300, Step: 13/17, Loss: 0.1956
# Epoch: 34/300, Step: 14/17, Loss: 0.1348
# Epoch: 34/300, Step: 15/17, Loss: 0.1846
# Epoch: 34/300, Step: 16/17, Loss: 0.1238
# Epoch: 35/300, Step: 1/17, Loss: 0.1744
# Epoch: 35/300, Step: 2/17, Loss: 0.1082
# Epoch: 35/300, Step: 3/17, Loss: 0.1063
# Epoch: 35/300, Step: 4/17, Loss: 0.1972
# Epoch: 35/300, Step: 5/17, Loss: 0.1849
# Epoch: 35/300, Step: 6/17, Loss: 0.1754
# Epoch: 35/300, Step: 7/17, Loss: 0.1141
# Epoch: 35/300, Step: 8/17, Loss: 0.0985
# Epoch: 35/300, Step: 9/17, Loss: 0.187
# Epoch: 35/300, Step: 10/17, Loss: 0.1114
# Epoch: 35/300, Step: 11/17, Loss: 0.0999
# Epoch: 35/300, Step: 12/17, Loss: 0.108
# Epoch: 35/300, Step: 13/17, Loss: 0.1069
# Epoch: 35/300, Step: 14/17, Loss: 0.185
# Epoch: 35/300, Step: 15/17, Loss: 0.179
# Epoch: 35/300, Step: 16/17, Loss: 0.163
# Epoch: 36/300, Step: 1/17, Loss: 0.0906
# Epoch: 36/300, Step: 2/17, Loss: 0.0953
# Epoch: 36/300, Step: 3/17, Loss: 0.1748
# Epoch: 36/300, Step: 4/17, Loss: 0.0968
# Epoch: 36/300, Step: 5/17, Loss: 0.16
# Epoch: 36/300, Step: 6/17, Loss: 0.0989
# Epoch: 36/300, Step: 7/17, Loss: 0.095
# Epoch: 36/300, Step: 8/17, Loss: 0.0877
# Epoch: 36/300, Step: 9/17, Loss: 0.0916
# Epoch: 36/300, Step: 10/17, Loss: 0.1697
# Epoch: 36/300, Step: 11/17, Loss: 0.1618
# Epoch: 36/300, Step: 12/17, Loss: 0.1641
# Epoch: 36/300, Step: 13/17, Loss: 0.0874
# Epoch: 36/300, Step: 14/17, Loss: 0.1612
# Epoch: 36/300, Step: 15/17, Loss: 0.1696
# Epoch: 36/300, Step: 16/17, Loss: 0.1085
# Epoch: 37/300, Step: 1/17, Loss: 0.1608
# Epoch: 37/300, Step: 2/17, Loss: 0.0784
# Epoch: 37/300, Step: 3/17, Loss: 0.0865
# Epoch: 37/300, Step: 4/17, Loss: 0.1515
# Epoch: 37/300, Step: 5/17, Loss: 0.0956
# Epoch: 37/300, Step: 6/17, Loss: 0.1432
# Epoch: 37/300, Step: 7/17, Loss: 0.0848
# Epoch: 37/300, Step: 8/17, Loss: 0.1417
# Epoch: 37/300, Step: 9/17, Loss: 0.1538
# Epoch: 37/300, Step: 10/17, Loss: 0.1511
# Epoch: 37/300, Step: 11/17, Loss: 0.0813
# Epoch: 37/300, Step: 12/17, Loss: 0.1404
# Epoch: 37/300, Step: 13/17, Loss: 0.1387
# Epoch: 37/300, Step: 14/17, Loss: 0.1452
# Epoch: 37/300, Step: 15/17, Loss: 0.136
# Epoch: 37/300, Step: 16/17, Loss: 0.1323
# Epoch: 38/300, Step: 1/17, Loss: 0.0837
# Epoch: 38/300, Step: 2/17, Loss: 0.1333
# Epoch: 38/300, Step: 3/17, Loss: 0.0764
# Epoch: 38/300, Step: 4/17, Loss: 0.0805
# Epoch: 38/300, Step: 5/17, Loss: 0.0827
# Epoch: 38/300, Step: 6/17, Loss: 0.0787
# Epoch: 38/300, Step: 7/17, Loss: 0.1188
# Epoch: 38/300, Step: 8/17, Loss: 0.1371
# Epoch: 38/300, Step: 9/17, Loss: 0.1278
# Epoch: 38/300, Step: 10/17, Loss: 0.1249
# Epoch: 38/300, Step: 11/17, Loss: 0.133
# Epoch: 38/300, Step: 12/17, Loss: 0.1162
# Epoch: 38/300, Step: 13/17, Loss: 0.1306
# Epoch: 38/300, Step: 14/17, Loss: 0.0785
# Epoch: 38/300, Step: 15/17, Loss: 0.1147
# Epoch: 38/300, Step: 16/17, Loss: 0.07
# Epoch: 39/300, Step: 1/17, Loss: 0.1138
# Epoch: 39/300, Step: 2/17, Loss: 0.073
# Epoch: 39/300, Step: 3/17, Loss: 0.1091
# Epoch: 39/300, Step: 4/17, Loss: 0.1198
# Epoch: 39/300, Step: 5/17, Loss: 0.0729
# Epoch: 39/300, Step: 6/17, Loss: 0.0672
# Epoch: 39/300, Step: 7/17, Loss: 0.0682
# Epoch: 39/300, Step: 8/17, Loss: 0.064
# Epoch: 39/300, Step: 9/17, Loss: 0.1148
# Epoch: 39/300, Step: 10/17, Loss: 0.1081
# Epoch: 39/300, Step: 11/17, Loss: 0.0637
# Epoch: 39/300, Step: 12/17, Loss: 0.0661
# Epoch: 39/300, Step: 13/17, Loss: 0.0621
# Epoch: 39/300, Step: 14/17, Loss: 0.1282
# Epoch: 39/300, Step: 15/17, Loss: 0.0744
# Epoch: 39/300, Step: 16/17, Loss: 0.0651
# Epoch: 40/300, Step: 1/17, Loss: 0.0757
# Epoch: 40/300, Step: 2/17, Loss: 0.1135
# Epoch: 40/300, Step: 3/17, Loss: 0.1315
# Epoch: 40/300, Step: 4/17, Loss: 0.1067
# Epoch: 40/300, Step: 5/17, Loss: 0.061
# Epoch: 40/300, Step: 6/17, Loss: 0.0744
# Epoch: 40/300, Step: 7/17, Loss: 0.1195
# Epoch: 40/300, Step: 8/17, Loss: 0.1383
# Epoch: 40/300, Step: 9/17, Loss: 0.1274
# Epoch: 40/300, Step: 10/17, Loss: 0.0794
# Epoch: 40/300, Step: 11/17, Loss: 0.0684
# Epoch: 40/300, Step: 12/17, Loss: 0.0723
# Epoch: 40/300, Step: 13/17, Loss: 0.1307
# Epoch: 40/300, Step: 14/17, Loss: 0.1744
# Epoch: 40/300, Step: 15/17, Loss: 0.0659
# Epoch: 40/300, Step: 16/17, Loss: 0.1275
# Epoch: 41/300, Step: 1/17, Loss: 0.0592
# Epoch: 41/300, Step: 2/17, Loss: 0.1126
# Epoch: 41/300, Step: 3/17, Loss: 0.1809
# Epoch: 41/300, Step: 4/17, Loss: 0.0902
# Epoch: 41/300, Step: 5/17, Loss: 2.5419
# Epoch: 41/300, Step: 6/17, Loss: 1.2697
# Epoch: 41/300, Step: 7/17, Loss: 0.8039
# Epoch: 41/300, Step: 8/17, Loss: 0.3489
# Epoch: 41/300, Step: 9/17, Loss: 0.4158
# Epoch: 41/300, Step: 10/17, Loss: 0.4177
# Epoch: 41/300, Step: 11/17, Loss: 0.6795
# Epoch: 41/300, Step: 12/17, Loss: 0.4294
# Epoch: 41/300, Step: 13/17, Loss: 0.2707
# Epoch: 41/300, Step: 14/17, Loss: 0.7574
# Epoch: 41/300, Step: 15/17, Loss: 0.4517
# Epoch: 41/300, Step: 16/17, Loss: 0.4294
# Epoch: 42/300, Step: 1/17, Loss: 0.4542
# Epoch: 42/300, Step: 2/17, Loss: 0.4157
# Epoch: 42/300, Step: 3/17, Loss: 0.2755
# Epoch: 42/300, Step: 4/17, Loss: 0.3672
# Epoch: 42/300, Step: 5/17, Loss: 0.2422
# Epoch: 42/300, Step: 6/17, Loss: 0.228
# Epoch: 42/300, Step: 7/17, Loss: 0.3396
# Epoch: 42/300, Step: 8/17, Loss: 0.3344
# Epoch: 42/300, Step: 9/17, Loss: 0.2831
# Epoch: 42/300, Step: 10/17, Loss: 0.2349
# Epoch: 42/300, Step: 11/17, Loss: 0.205
# Epoch: 42/300, Step: 12/17, Loss: 0.2432
# Epoch: 42/300, Step: 13/17, Loss: 0.246
# Epoch: 42/300, Step: 14/17, Loss: 0.1403
# Epoch: 42/300, Step: 15/17, Loss: 0.205
# Epoch: 42/300, Step: 16/17, Loss: 0.1239
# Epoch: 43/300, Step: 1/17, Loss: 0.1145
# Epoch: 43/300, Step: 2/17, Loss: 0.1865
# Epoch: 43/300, Step: 3/17, Loss: 0.1809
# Epoch: 43/300, Step: 4/17, Loss: 0.1024
# Epoch: 43/300, Step: 5/17, Loss: 0.0968
# Epoch: 43/300, Step: 6/17, Loss: 0.0989
# Epoch: 43/300, Step: 7/17, Loss: 0.0871
# Epoch: 43/300, Step: 8/17, Loss: 0.097
# Epoch: 43/300, Step: 9/17, Loss: 0.0832
# Epoch: 43/300, Step: 10/17, Loss: 0.1376
# Epoch: 43/300, Step: 11/17, Loss: 0.1332
# Epoch: 43/300, Step: 12/17, Loss: 0.074
# Epoch: 43/300, Step: 13/17, Loss: 0.1289
# Epoch: 43/300, Step: 14/17, Loss: 0.1133
# Epoch: 43/300, Step: 15/17, Loss: 0.0651
# Epoch: 43/300, Step: 16/17, Loss: 0.1213
# Epoch: 44/300, Step: 1/17, Loss: 0.0638
# Epoch: 44/300, Step: 2/17, Loss: 0.0672
# Epoch: 44/300, Step: 3/17, Loss: 0.1008
# Epoch: 44/300, Step: 4/17, Loss: 0.1164
# Epoch: 44/300, Step: 5/17, Loss: 0.0585
# Epoch: 44/300, Step: 6/17, Loss: 0.1072
# Epoch: 44/300, Step: 7/17, Loss: 0.0671
# Epoch: 44/300, Step: 8/17, Loss: 0.1101
# Epoch: 44/300, Step: 9/17, Loss: 0.0997
# Epoch: 44/300, Step: 10/17, Loss: 0.0979
# Epoch: 44/300, Step: 11/17, Loss: 0.097
# Epoch: 44/300, Step: 12/17, Loss: 0.0574
# Epoch: 44/300, Step: 13/17, Loss: 0.0914
# Epoch: 44/300, Step: 14/17, Loss: 0.0552
# Epoch: 44/300, Step: 15/17, Loss: 0.0932
# Epoch: 44/300, Step: 16/17, Loss: 0.0982
# Epoch: 45/300, Step: 1/17, Loss: 0.0476
# Epoch: 45/300, Step: 2/17, Loss: 0.0837
# Epoch: 45/300, Step: 3/17, Loss: 0.0509
# Epoch: 45/300, Step: 4/17, Loss: 0.0488
# Epoch: 45/300, Step: 5/17, Loss: 0.0965
# Epoch: 45/300, Step: 6/17, Loss: 0.0878
# Epoch: 45/300, Step: 7/17, Loss: 0.0486
# Epoch: 45/300, Step: 8/17, Loss: 0.0877
# Epoch: 45/300, Step: 9/17, Loss: 0.0855
# Epoch: 45/300, Step: 10/17, Loss: 0.0865
# Epoch: 45/300, Step: 11/17, Loss: 0.0473
# Epoch: 45/300, Step: 12/17, Loss: 0.08
# Epoch: 45/300, Step: 13/17, Loss: 0.0428
# Epoch: 45/300, Step: 14/17, Loss: 0.0485
# Epoch: 45/300, Step: 15/17, Loss: 0.0432
# Epoch: 45/300, Step: 16/17, Loss: 0.047
# Epoch: 46/300, Step: 1/17, Loss: 0.0428
# Epoch: 46/300, Step: 2/17, Loss: 0.0421
# Epoch: 46/300, Step: 3/17, Loss: 0.0438
# Epoch: 46/300, Step: 4/17, Loss: 0.0834
# Epoch: 46/300, Step: 5/17, Loss: 0.0422
# Epoch: 46/300, Step: 6/17, Loss: 0.0411
# Epoch: 46/300, Step: 7/17, Loss: 0.0396
# Epoch: 46/300, Step: 8/17, Loss: 0.0357
# Epoch: 46/300, Step: 9/17, Loss: 0.0787
# Epoch: 46/300, Step: 10/17, Loss: 0.0729
# Epoch: 46/300, Step: 11/17, Loss: 0.0807
# Epoch: 46/300, Step: 12/17, Loss: 0.0755
# Epoch: 46/300, Step: 13/17, Loss: 0.0366
# Epoch: 46/300, Step: 14/17, Loss: 0.0435
# Epoch: 46/300, Step: 15/17, Loss: 0.0385
# Epoch: 46/300, Step: 16/17, Loss: 0.0719
# Epoch: 47/300, Step: 1/17, Loss: 0.0352
# Epoch: 47/300, Step: 2/17, Loss: 0.0377
# Epoch: 47/300, Step: 3/17, Loss: 0.0348
# Epoch: 47/300, Step: 4/17, Loss: 0.0718
# Epoch: 47/300, Step: 5/17, Loss: 0.0742
# Epoch: 47/300, Step: 6/17, Loss: 0.0648
# Epoch: 47/300, Step: 7/17, Loss: 0.0348
# Epoch: 47/300, Step: 8/17, Loss: 0.0743
# Epoch: 47/300, Step: 9/17, Loss: 0.0387
# Epoch: 47/300, Step: 10/17, Loss: 0.0692
# Epoch: 47/300, Step: 11/17, Loss: 0.0559
# Epoch: 47/300, Step: 12/17, Loss: 0.0354
# Epoch: 47/300, Step: 13/17, Loss: 0.0659
# Epoch: 47/300, Step: 14/17, Loss: 0.0683
# Epoch: 47/300, Step: 15/17, Loss: 0.0671
# Epoch: 47/300, Step: 16/17, Loss: 0.068
# Epoch: 48/300, Step: 1/17, Loss: 0.0352
# Epoch: 48/300, Step: 2/17, Loss: 0.0608
# Epoch: 48/300, Step: 3/17, Loss: 0.0305
# Epoch: 48/300, Step: 4/17, Loss: 0.0298
# Epoch: 48/300, Step: 5/17, Loss: 0.0639
# Epoch: 48/300, Step: 6/17, Loss: 0.0337
# Epoch: 48/300, Step: 7/17, Loss: 0.0677
# Epoch: 48/300, Step: 8/17, Loss: 0.063
# Epoch: 48/300, Step: 9/17, Loss: 0.033
# Epoch: 48/300, Step: 10/17, Loss: 0.0325
# Epoch: 48/300, Step: 11/17, Loss: 0.068
# Epoch: 48/300, Step: 12/17, Loss: 0.0352
# Epoch: 48/300, Step: 13/17, Loss: 0.0567
# Epoch: 48/300, Step: 14/17, Loss: 0.0328
# Epoch: 48/300, Step: 15/17, Loss: 0.0346
# Epoch: 48/300, Step: 16/17, Loss: 0.0309
# Epoch: 49/300, Step: 1/17, Loss: 0.0558
# Epoch: 49/300, Step: 2/17, Loss: 0.0311
# Epoch: 49/300, Step: 3/17, Loss: 0.0635
# Epoch: 49/300, Step: 4/17, Loss: 0.0279
# Epoch: 49/300, Step: 5/17, Loss: 0.0579
# Epoch: 49/300, Step: 6/17, Loss: 0.0527
# Epoch: 49/300, Step: 7/17, Loss: 0.0521
# Epoch: 49/300, Step: 8/17, Loss: 0.0515
# Epoch: 49/300, Step: 9/17, Loss: 0.0298
# Epoch: 49/300, Step: 10/17, Loss: 0.0316
# Epoch: 49/300, Step: 11/17, Loss: 0.0333
# Epoch: 49/300, Step: 12/17, Loss: 0.06
# Epoch: 49/300, Step: 13/17, Loss: 0.0303
# Epoch: 49/300, Step: 14/17, Loss: 0.028
# Epoch: 49/300, Step: 15/17, Loss: 0.03
# Epoch: 49/300, Step: 16/17, Loss: 0.0529
# Epoch: 50/300, Step: 1/17, Loss: 0.0258
# Epoch: 50/300, Step: 2/17, Loss: 0.0559
# Epoch: 50/300, Step: 3/17, Loss: 0.0255
# Epoch: 50/300, Step: 4/17, Loss: 0.0518
# Epoch: 50/300, Step: 5/17, Loss: 0.0499
# Epoch: 50/300, Step: 6/17, Loss: 0.025
# Epoch: 50/300, Step: 7/17, Loss: 0.055
# Epoch: 50/300, Step: 8/17, Loss: 0.027
# Epoch: 50/300, Step: 9/17, Loss: 0.0265
# Epoch: 50/300, Step: 10/17, Loss: 0.0288
# Epoch: 50/300, Step: 11/17, Loss: 0.0593
# Epoch: 50/300, Step: 12/17, Loss: 0.0588
# Epoch: 50/300, Step: 13/17, Loss: 0.0535
# Epoch: 50/300, Step: 14/17, Loss: 0.0537
# Epoch: 50/300, Step: 15/17, Loss: 0.055
# Epoch: 50/300, Step: 16/17, Loss: 0.0253
# Epoch: 51/300, Step: 1/17, Loss: 0.0463
# Epoch: 51/300, Step: 2/17, Loss: 0.0238
# Epoch: 51/300, Step: 3/17, Loss: 0.0525
# Epoch: 51/300, Step: 4/17, Loss: 0.024
# Epoch: 51/300, Step: 5/17, Loss: 0.0252
# Epoch: 51/300, Step: 6/17, Loss: 0.0558
# Epoch: 51/300, Step: 7/17, Loss: 0.0237
# Epoch: 51/300, Step: 8/17, Loss: 0.0266
# Epoch: 51/300, Step: 9/17, Loss: 0.0488
# Epoch: 51/300, Step: 10/17, Loss: 0.0248
# Epoch: 51/300, Step: 11/17, Loss: 0.0229
# Epoch: 51/300, Step: 12/17, Loss: 0.0271
# Epoch: 51/300, Step: 13/17, Loss: 0.0534
# Epoch: 51/300, Step: 14/17, Loss: 0.0501
# Epoch: 51/300, Step: 15/17, Loss: 0.0428
# Epoch: 51/300, Step: 16/17, Loss: 0.0258
# Epoch: 52/300, Step: 1/17, Loss: 0.0213
# Epoch: 52/300, Step: 2/17, Loss: 0.0477
# Epoch: 52/300, Step: 3/17, Loss: 0.0478
# Epoch: 52/300, Step: 4/17, Loss: 0.0238
# Epoch: 52/300, Step: 5/17, Loss: 0.0459
# Epoch: 52/300, Step: 6/17, Loss: 0.0221
# Epoch: 52/300, Step: 7/17, Loss: 0.0226
# Epoch: 52/300, Step: 8/17, Loss: 0.0217
# Epoch: 52/300, Step: 9/17, Loss: 0.0486
# Epoch: 52/300, Step: 10/17, Loss: 0.0209
# Epoch: 52/300, Step: 11/17, Loss: 0.0226
# Epoch: 52/300, Step: 12/17, Loss: 0.0455
# Epoch: 52/300, Step: 13/17, Loss: 0.0252
# Epoch: 52/300, Step: 14/17, Loss: 0.0484
# Epoch: 52/300, Step: 15/17, Loss: 0.0221
# Epoch: 52/300, Step: 16/17, Loss: 0.0417
# Epoch: 53/300, Step: 1/17, Loss: 0.0189
# Epoch: 53/300, Step: 2/17, Loss: 0.0486
# Epoch: 53/300, Step: 3/17, Loss: 0.0388
# Epoch: 53/300, Step: 4/17, Loss: 0.0438
# Epoch: 53/300, Step: 5/17, Loss: 0.0413
# Epoch: 53/300, Step: 6/17, Loss: 0.0411
# Epoch: 53/300, Step: 7/17, Loss: 0.0416
# Epoch: 53/300, Step: 8/17, Loss: 0.0416
# Epoch: 53/300, Step: 9/17, Loss: 0.0219
# Epoch: 53/300, Step: 10/17, Loss: 0.023
# Epoch: 53/300, Step: 11/17, Loss: 0.0403
# Epoch: 53/300, Step: 12/17, Loss: 0.044
# Epoch: 53/300, Step: 13/17, Loss: 0.0415
# Epoch: 53/300, Step: 14/17, Loss: 0.0208
# Epoch: 53/300, Step: 15/17, Loss: 0.0476
# Epoch: 53/300, Step: 16/17, Loss: 0.0214
# Epoch: 54/300, Step: 1/17, Loss: 0.02
# Epoch: 54/300, Step: 2/17, Loss: 0.0397
# Epoch: 54/300, Step: 3/17, Loss: 0.0203
# Epoch: 54/300, Step: 4/17, Loss: 0.0205
# Epoch: 54/300, Step: 5/17, Loss: 0.0394
# Epoch: 54/300, Step: 6/17, Loss: 0.0217
# Epoch: 54/300, Step: 7/17, Loss: 0.0225
# Epoch: 54/300, Step: 8/17, Loss: 0.0205
# Epoch: 54/300, Step: 9/17, Loss: 0.0179
# Epoch: 54/300, Step: 10/17, Loss: 0.0198
# Epoch: 54/300, Step: 11/17, Loss: 0.0205
# Epoch: 54/300, Step: 12/17, Loss: 0.0372
# Epoch: 54/300, Step: 13/17, Loss: 0.0191
# Epoch: 54/300, Step: 14/17, Loss: 0.035
# Epoch: 54/300, Step: 15/17, Loss: 0.0352
# Epoch: 54/300, Step: 16/17, Loss: 0.037
# Epoch: 55/300, Step: 1/17, Loss: 0.0191
# Epoch: 55/300, Step: 2/17, Loss: 0.017
# Epoch: 55/300, Step: 3/17, Loss: 0.0354
# Epoch: 55/300, Step: 4/17, Loss: 0.0181
# Epoch: 55/300, Step: 5/17, Loss: 0.0366
# Epoch: 55/300, Step: 6/17, Loss: 0.0387
# Epoch: 55/300, Step: 7/17, Loss: 0.0331
# Epoch: 55/300, Step: 8/17, Loss: 0.0373
# Epoch: 55/300, Step: 9/17, Loss: 0.0198
# Epoch: 55/300, Step: 10/17, Loss: 0.0367
# Epoch: 55/300, Step: 11/17, Loss: 0.017
# Epoch: 55/300, Step: 12/17, Loss: 0.0394
# Epoch: 55/300, Step: 13/17, Loss: 0.036
# Epoch: 55/300, Step: 14/17, Loss: 0.0178
# Epoch: 55/300, Step: 15/17, Loss: 0.0175
# Epoch: 55/300, Step: 16/17, Loss: 0.0178
# Epoch: 56/300, Step: 1/17, Loss: 0.0163
# Epoch: 56/300, Step: 2/17, Loss: 0.0344
# Epoch: 56/300, Step: 3/17, Loss: 0.0175
# Epoch: 56/300, Step: 4/17, Loss: 0.0161
# Epoch: 56/300, Step: 5/17, Loss: 0.0369
# Epoch: 56/300, Step: 6/17, Loss: 0.0376
# Epoch: 56/300, Step: 7/17, Loss: 0.0374
# Epoch: 56/300, Step: 8/17, Loss: 0.0179
# Epoch: 56/300, Step: 9/17, Loss: 0.0182
# Epoch: 56/300, Step: 10/17, Loss: 0.0169
# Epoch: 56/300, Step: 11/17, Loss: 0.0183
# Epoch: 56/300, Step: 12/17, Loss: 0.0137
# Epoch: 56/300, Step: 13/17, Loss: 0.0389
# Epoch: 56/300, Step: 14/17, Loss: 0.0353
# Epoch: 56/300, Step: 15/17, Loss: 0.0171
# Epoch: 56/300, Step: 16/17, Loss: 0.0197
# Epoch: 57/300, Step: 1/17, Loss: 0.0172
# Epoch: 57/300, Step: 2/17, Loss: 0.0172
# Epoch: 57/300, Step: 3/17, Loss: 0.0166
# Epoch: 57/300, Step: 4/17, Loss: 0.0341
# Epoch: 57/300, Step: 5/17, Loss: 0.0384
# Epoch: 57/300, Step: 6/17, Loss: 0.016
# Epoch: 57/300, Step: 7/17, Loss: 0.0346
# Epoch: 57/300, Step: 8/17, Loss: 0.032
# Epoch: 57/300, Step: 9/17, Loss: 0.0334
# Epoch: 57/300, Step: 10/17, Loss: 0.0143
# Epoch: 57/300, Step: 11/17, Loss: 0.0158
# Epoch: 57/300, Step: 12/17, Loss: 0.033
# Epoch: 57/300, Step: 13/17, Loss: 0.0146
# Epoch: 57/300, Step: 14/17, Loss: 0.0155
# Epoch: 57/300, Step: 15/17, Loss: 0.0147
# Epoch: 57/300, Step: 16/17, Loss: 0.014
# Epoch: 58/300, Step: 1/17, Loss: 0.0141
# Epoch: 58/300, Step: 2/17, Loss: 0.0137
# Epoch: 58/300, Step: 3/17, Loss: 0.0158
# Epoch: 58/300, Step: 4/17, Loss: 0.031
# Epoch: 58/300, Step: 5/17, Loss: 0.0145
# Epoch: 58/300, Step: 6/17, Loss: 0.0134
# Epoch: 58/300, Step: 7/17, Loss: 0.0134
# Epoch: 58/300, Step: 8/17, Loss: 0.0126
# Epoch: 58/300, Step: 9/17, Loss: 0.0137
# Epoch: 58/300, Step: 10/17, Loss: 0.0337
# Epoch: 58/300, Step: 11/17, Loss: 0.0283
# Epoch: 58/300, Step: 12/17, Loss: 0.0311
# Epoch: 58/300, Step: 13/17, Loss: 0.0305
# Epoch: 58/300, Step: 14/17, Loss: 0.0299
# Epoch: 58/300, Step: 15/17, Loss: 0.0315
# Epoch: 58/300, Step: 16/17, Loss: 0.0132
# Epoch: 59/300, Step: 1/17, Loss: 0.0127
# Epoch: 59/300, Step: 2/17, Loss: 0.0128
# Epoch: 59/300, Step: 3/17, Loss: 0.0313
# Epoch: 59/300, Step: 4/17, Loss: 0.0137
# Epoch: 59/300, Step: 5/17, Loss: 0.0299
# Epoch: 59/300, Step: 6/17, Loss: 0.0132
# Epoch: 59/300, Step: 7/17, Loss: 0.014
# Epoch: 59/300, Step: 8/17, Loss: 0.0292
# Epoch: 59/300, Step: 9/17, Loss: 0.0254
# Epoch: 59/300, Step: 10/17, Loss: 0.0151
# Epoch: 59/300, Step: 11/17, Loss: 0.0143
# Epoch: 59/300, Step: 12/17, Loss: 0.0234
# Epoch: 59/300, Step: 13/17, Loss: 0.0278
# Epoch: 59/300, Step: 14/17, Loss: 0.0129
# Epoch: 59/300, Step: 15/17, Loss: 0.0132
# Epoch: 59/300, Step: 16/17, Loss: 0.0133
# Epoch: 60/300, Step: 1/17, Loss: 0.0245
# Epoch: 60/300, Step: 2/17, Loss: 0.0295
# Epoch: 60/300, Step: 3/17, Loss: 0.0269
# Epoch: 60/300, Step: 4/17, Loss: 0.0114
# Epoch: 60/300, Step: 5/17, Loss: 0.0276
# Epoch: 60/300, Step: 6/17, Loss: 0.0249
# Epoch: 60/300, Step: 7/17, Loss: 0.0282
# Epoch: 60/300, Step: 8/17, Loss: 0.0258
# Epoch: 60/300, Step: 9/17, Loss: 0.0111
# Epoch: 60/300, Step: 10/17, Loss: 0.0243
# Epoch: 60/300, Step: 11/17, Loss: 0.0159
# Epoch: 60/300, Step: 12/17, Loss: 0.0265
# Epoch: 60/300, Step: 13/17, Loss: 0.013
# Epoch: 60/300, Step: 14/17, Loss: 0.0125
# Epoch: 60/300, Step: 15/17, Loss: 0.025
# Epoch: 60/300, Step: 16/17, Loss: 0.0246
# Epoch: 61/300, Step: 1/17, Loss: 0.0251
# Epoch: 61/300, Step: 2/17, Loss: 0.0115
# Epoch: 61/300, Step: 3/17, Loss: 0.0217
# Epoch: 61/300, Step: 4/17, Loss: 0.0108
# Epoch: 61/300, Step: 5/17, Loss: 0.0247
# Epoch: 61/300, Step: 6/17, Loss: 0.0233
# Epoch: 61/300, Step: 7/17, Loss: 0.0102
# Epoch: 61/300, Step: 8/17, Loss: 0.0132
# Epoch: 61/300, Step: 9/17, Loss: 0.0267
# Epoch: 61/300, Step: 10/17, Loss: 0.013
# Epoch: 61/300, Step: 11/17, Loss: 0.0114
# Epoch: 61/300, Step: 12/17, Loss: 0.0268
# Epoch: 61/300, Step: 13/17, Loss: 0.0135
# Epoch: 61/300, Step: 14/17, Loss: 0.0247
# Epoch: 61/300, Step: 15/17, Loss: 0.0225
# Epoch: 61/300, Step: 16/17, Loss: 0.0116
# Epoch: 62/300, Step: 1/17, Loss: 0.0115
# Epoch: 62/300, Step: 2/17, Loss: 0.0243
# Epoch: 62/300, Step: 3/17, Loss: 0.0116
# Epoch: 62/300, Step: 4/17, Loss: 0.0237
# Epoch: 62/300, Step: 5/17, Loss: 0.0115
# Epoch: 62/300, Step: 6/17, Loss: 0.0241
# Epoch: 62/300, Step: 7/17, Loss: 0.0105
# Epoch: 62/300, Step: 8/17, Loss: 0.0219
# Epoch: 62/300, Step: 9/17, Loss: 0.0114
# Epoch: 62/300, Step: 10/17, Loss: 0.0113
# Epoch: 62/300, Step: 11/17, Loss: 0.019
# Epoch: 62/300, Step: 12/17, Loss: 0.0193
# Epoch: 62/300, Step: 13/17, Loss: 0.0109
# Epoch: 62/300, Step: 14/17, Loss: 0.0095
# Epoch: 62/300, Step: 15/17, Loss: 0.0226
# Epoch: 62/300, Step: 16/17, Loss: 0.0233
# Epoch: 63/300, Step: 1/17, Loss: 0.0215
# Epoch: 63/300, Step: 2/17, Loss: 0.0104
# Epoch: 63/300, Step: 3/17, Loss: 0.0252
# Epoch: 63/300, Step: 4/17, Loss: 0.0127
# Epoch: 63/300, Step: 5/17, Loss: 0.02
# Epoch: 63/300, Step: 6/17, Loss: 0.0205
# Epoch: 63/300, Step: 7/17, Loss: 0.0189
# Epoch: 63/300, Step: 8/17, Loss: 0.0207
# Epoch: 63/300, Step: 9/17, Loss: 0.0098
# Epoch: 63/300, Step: 10/17, Loss: 0.0103
# Epoch: 63/300, Step: 11/17, Loss: 0.0103
# Epoch: 63/300, Step: 12/17, Loss: 0.018
# Epoch: 63/300, Step: 13/17, Loss: 0.0108
# Epoch: 63/300, Step: 14/17, Loss: 0.0108
# Epoch: 63/300, Step: 15/17, Loss: 0.0195
# Epoch: 63/300, Step: 16/17, Loss: 0.0205
# Epoch: 64/300, Step: 1/17, Loss: 0.0091
# Epoch: 64/300, Step: 2/17, Loss: 0.0092
# Epoch: 64/300, Step: 3/17, Loss: 0.0196
# Epoch: 64/300, Step: 4/17, Loss: 0.0192
# Epoch: 64/300, Step: 5/17, Loss: 0.009
# Epoch: 64/300, Step: 6/17, Loss: 0.0209
# Epoch: 64/300, Step: 7/17, Loss: 0.0092
# Epoch: 64/300, Step: 8/17, Loss: 0.0196
# Epoch: 64/300, Step: 9/17, Loss: 0.0219
# Epoch: 64/300, Step: 10/17, Loss: 0.0086
# Epoch: 64/300, Step: 11/17, Loss: 0.0195
# Epoch: 64/300, Step: 12/17, Loss: 0.0193
# Epoch: 64/300, Step: 13/17, Loss: 0.0191
# Epoch: 64/300, Step: 14/17, Loss: 0.019
# Epoch: 64/300, Step: 15/17, Loss: 0.0201
# Epoch: 64/300, Step: 16/17, Loss: 0.0106
# Epoch: 65/300, Step: 1/17, Loss: 0.0184
# Epoch: 65/300, Step: 2/17, Loss: 0.0193
# Epoch: 65/300, Step: 3/17, Loss: 0.0153
# Epoch: 65/300, Step: 4/17, Loss: 0.019
# Epoch: 65/300, Step: 5/17, Loss: 0.01
# Epoch: 65/300, Step: 6/17, Loss: 0.0203
# Epoch: 65/300, Step: 7/17, Loss: 0.0191
# Epoch: 65/300, Step: 8/17, Loss: 0.01
# Epoch: 65/300, Step: 9/17, Loss: 0.0174
# Epoch: 65/300, Step: 10/17, Loss: 0.0163
# Epoch: 65/300, Step: 11/17, Loss: 0.0096
# Epoch: 65/300, Step: 12/17, Loss: 0.0191
# Epoch: 65/300, Step: 13/17, Loss: 0.0094
# Epoch: 65/300, Step: 14/17, Loss: 0.0176
# Epoch: 65/300, Step: 15/17, Loss: 0.016
# Epoch: 65/300, Step: 16/17, Loss: 0.017
# Epoch: 66/300, Step: 1/17, Loss: 0.0087
# Epoch: 66/300, Step: 2/17, Loss: 0.0177
# Epoch: 66/300, Step: 3/17, Loss: 0.0081
# Epoch: 66/300, Step: 4/17, Loss: 0.0165
# Epoch: 66/300, Step: 5/17, Loss: 0.0164
# Epoch: 66/300, Step: 6/17, Loss: 0.0088
# Epoch: 66/300, Step: 7/17, Loss: 0.0174
# Epoch: 66/300, Step: 8/17, Loss: 0.0164
# Epoch: 66/300, Step: 9/17, Loss: 0.0159
# Epoch: 66/300, Step: 10/17, Loss: 0.0113
# Epoch: 66/300, Step: 11/17, Loss: 0.0095
# Epoch: 66/300, Step: 12/17, Loss: 0.0158
# Epoch: 66/300, Step: 13/17, Loss: 0.014
# Epoch: 66/300, Step: 14/17, Loss: 0.0165
# Epoch: 66/300, Step: 15/17, Loss: 0.0169
# Epoch: 66/300, Step: 16/17, Loss: 0.0172
# Epoch: 67/300, Step: 1/17, Loss: 0.0165
# Epoch: 67/300, Step: 2/17, Loss: 0.0085
# Epoch: 67/300, Step: 3/17, Loss: 0.0149
# Epoch: 67/300, Step: 4/17, Loss: 0.0082
# Epoch: 67/300, Step: 5/17, Loss: 0.0145
# Epoch: 67/300, Step: 6/17, Loss: 0.0084
# Epoch: 67/300, Step: 7/17, Loss: 0.0089
# Epoch: 67/300, Step: 8/17, Loss: 0.0086
# Epoch: 67/300, Step: 9/17, Loss: 0.0106
# Epoch: 67/300, Step: 10/17, Loss: 0.0088
# Epoch: 67/300, Step: 11/17, Loss: 0.0161
# Epoch: 67/300, Step: 12/17, Loss: 0.0121
# Epoch: 67/300, Step: 13/17, Loss: 0.0153
# Epoch: 67/300, Step: 14/17, Loss: 0.0139
# Epoch: 67/300, Step: 15/17, Loss: 0.0152
# Epoch: 67/300, Step: 16/17, Loss: 0.0083
# Epoch: 68/300, Step: 1/17, Loss: 0.008
# Epoch: 68/300, Step: 2/17, Loss: 0.015
# Epoch: 68/300, Step: 3/17, Loss: 0.0069
# Epoch: 68/300, Step: 4/17, Loss: 0.015
# Epoch: 68/300, Step: 5/17, Loss: 0.0149
# Epoch: 68/300, Step: 6/17, Loss: 0.0079
# Epoch: 68/300, Step: 7/17, Loss: 0.0072
# Epoch: 68/300, Step: 8/17, Loss: 0.0166
# Epoch: 68/300, Step: 9/17, Loss: 0.0079
# Epoch: 68/300, Step: 10/17, Loss: 0.0148
# Epoch: 68/300, Step: 11/17, Loss: 0.0078
# Epoch: 68/300, Step: 12/17, Loss: 0.0131
# Epoch: 68/300, Step: 13/17, Loss: 0.0083
# Epoch: 68/300, Step: 14/17, Loss: 0.0127
# Epoch: 68/300, Step: 15/17, Loss: 0.0077
# Epoch: 68/300, Step: 16/17, Loss: 0.0086
# Epoch: 69/300, Step: 1/17, Loss: 0.0073
# Epoch: 69/300, Step: 2/17, Loss: 0.0141
# Epoch: 69/300, Step: 3/17, Loss: 0.0076
# Epoch: 69/300, Step: 4/17, Loss: 0.0073
# Epoch: 69/300, Step: 5/17, Loss: 0.0134
# Epoch: 69/300, Step: 6/17, Loss: 0.0065
# Epoch: 69/300, Step: 7/17, Loss: 0.007
# Epoch: 69/300, Step: 8/17, Loss: 0.016
# Epoch: 69/300, Step: 9/17, Loss: 0.0138
# Epoch: 69/300, Step: 10/17, Loss: 0.0129
# Epoch: 69/300, Step: 11/17, Loss: 0.0068
# Epoch: 69/300, Step: 12/17, Loss: 0.0136
# Epoch: 69/300, Step: 13/17, Loss: 0.0143
# Epoch: 69/300, Step: 14/17, Loss: 0.0121
# Epoch: 69/300, Step: 15/17, Loss: 0.0078
# Epoch: 69/300, Step: 16/17, Loss: 0.0076
# Epoch: 70/300, Step: 1/17, Loss: 0.0064
# Epoch: 70/300, Step: 2/17, Loss: 0.007
# Epoch: 70/300, Step: 3/17, Loss: 0.0128
# Epoch: 70/300, Step: 4/17, Loss: 0.0164
# Epoch: 70/300, Step: 5/17, Loss: 0.0068
# Epoch: 70/300, Step: 6/17, Loss: 0.0066
# Epoch: 70/300, Step: 7/17, Loss: 0.012
# Epoch: 70/300, Step: 8/17, Loss: 0.011
# Epoch: 70/300, Step: 9/17, Loss: 0.0066
# Epoch: 70/300, Step: 10/17, Loss: 0.0134
# Epoch: 70/300, Step: 11/17, Loss: 0.0133
# Epoch: 70/300, Step: 12/17, Loss: 0.007
# Epoch: 70/300, Step: 13/17, Loss: 0.0072
# Epoch: 70/300, Step: 14/17, Loss: 0.0133
# Epoch: 70/300, Step: 15/17, Loss: 0.0136
# Epoch: 70/300, Step: 16/17, Loss: 0.0123
# Epoch: 71/300, Step: 1/17, Loss: 0.0056
# Epoch: 71/300, Step: 2/17, Loss: 0.0072
# Epoch: 71/300, Step: 3/17, Loss: 0.007
# Epoch: 71/300, Step: 4/17, Loss: 0.0117
# Epoch: 71/300, Step: 5/17, Loss: 0.0061
# Epoch: 71/300, Step: 6/17, Loss: 0.0129
# Epoch: 71/300, Step: 7/17, Loss: 0.0114
# Epoch: 71/300, Step: 8/17, Loss: 0.0067
# Epoch: 71/300, Step: 9/17, Loss: 0.0061
# Epoch: 71/300, Step: 10/17, Loss: 0.0124
# Epoch: 71/300, Step: 11/17, Loss: 0.0071
# Epoch: 71/300, Step: 12/17, Loss: 0.0085
# Epoch: 71/300, Step: 13/17, Loss: 0.0127
# Epoch: 71/300, Step: 14/17, Loss: 0.0064
# Epoch: 71/300, Step: 15/17, Loss: 0.0125
# Epoch: 71/300, Step: 16/17, Loss: 0.0118
# Epoch: 72/300, Step: 1/17, Loss: 0.0076
# Epoch: 72/300, Step: 2/17, Loss: 0.0063
# Epoch: 72/300, Step: 3/17, Loss: 0.0126
# Epoch: 72/300, Step: 4/17, Loss: 0.0061
# Epoch: 72/300, Step: 5/17, Loss: 0.0123
# Epoch: 72/300, Step: 6/17, Loss: 0.012
# Epoch: 72/300, Step: 7/17, Loss: 0.0123
# Epoch: 72/300, Step: 8/17, Loss: 0.0107
# Epoch: 72/300, Step: 9/17, Loss: 0.0105
# Epoch: 72/300, Step: 10/17, Loss: 0.0067
# Epoch: 72/300, Step: 11/17, Loss: 0.0065
# Epoch: 72/300, Step: 12/17, Loss: 0.0123
# Epoch: 72/300, Step: 13/17, Loss: 0.0101
# Epoch: 72/300, Step: 14/17, Loss: 0.006
# Epoch: 72/300, Step: 15/17, Loss: 0.0062
# Epoch: 72/300, Step: 16/17, Loss: 0.0056
# Epoch: 73/300, Step: 1/17, Loss: 0.0065
# Epoch: 73/300, Step: 2/17, Loss: 0.0055
# Epoch: 73/300, Step: 3/17, Loss: 0.0116
# Epoch: 73/300, Step: 4/17, Loss: 0.0059
# Epoch: 73/300, Step: 5/17, Loss: 0.0058
# Epoch: 73/300, Step: 6/17, Loss: 0.0062
# Epoch: 73/300, Step: 7/17, Loss: 0.0115
# Epoch: 73/300, Step: 8/17, Loss: 0.0101
# Epoch: 73/300, Step: 9/17, Loss: 0.0115
# Epoch: 73/300, Step: 10/17, Loss: 0.0106
# Epoch: 73/300, Step: 11/17, Loss: 0.0053
# Epoch: 73/300, Step: 12/17, Loss: 0.0056
# Epoch: 73/300, Step: 13/17, Loss: 0.0054
# Epoch: 73/300, Step: 14/17, Loss: 0.0141
# Epoch: 73/300, Step: 15/17, Loss: 0.0053
# Epoch: 73/300, Step: 16/17, Loss: 0.0058
# Epoch: 74/300, Step: 1/17, Loss: 0.0055
# Epoch: 74/300, Step: 2/17, Loss: 0.0119
# Epoch: 74/300, Step: 3/17, Loss: 0.0055
# Epoch: 74/300, Step: 4/17, Loss: 0.0052
# Epoch: 74/300, Step: 5/17, Loss: 0.005
# Epoch: 74/300, Step: 6/17, Loss: 0.0055
# Epoch: 74/300, Step: 7/17, Loss: 0.0056
# Epoch: 74/300, Step: 8/17, Loss: 0.0113
# Epoch: 74/300, Step: 9/17, Loss: 0.0053
# Epoch: 74/300, Step: 10/17, Loss: 0.0055
# Epoch: 74/300, Step: 11/17, Loss: 0.0053
# Epoch: 74/300, Step: 12/17, Loss: 0.0105
# Epoch: 74/300, Step: 13/17, Loss: 0.0055
# Epoch: 74/300, Step: 14/17, Loss: 0.0112
# Epoch: 74/300, Step: 15/17, Loss: 0.005
# Epoch: 74/300, Step: 16/17, Loss: 0.0056
# Epoch: 75/300, Step: 1/17, Loss: 0.0118
# Epoch: 75/300, Step: 2/17, Loss: 0.0053
# Epoch: 75/300, Step: 3/17, Loss: 0.0058
# Epoch: 75/300, Step: 4/17, Loss: 0.0095
# Epoch: 75/300, Step: 5/17, Loss: 0.0093
# Epoch: 75/300, Step: 6/17, Loss: 0.0052
# Epoch: 75/300, Step: 7/17, Loss: 0.0049
# Epoch: 75/300, Step: 8/17, Loss: 0.0099
# Epoch: 75/300, Step: 9/17, Loss: 0.0051
# ...
# Epoch: 276/300, Step: 16/17, Loss: 0.0002
# Epoch: 277/300, Step: 1/17, Loss: 0.0002
# Epoch: 277/300, Step: 2/17, Loss: 0.0002
# Epoch: 277/300, Step: 3/17, Loss: 0.0001
# Epoch: 277/300, Step: 4/17, Loss: 0.0002
# Epoch: 277/300, Step: 5/17, Loss: 0.0002
# Epoch: 277/300, Step: 6/17, Loss: 0.0002
# Epoch: 277/300, Step: 7/17, Loss: 0.0001
# Epoch: 277/300, Step: 8/17, Loss: 0.0001
# Epoch: 277/300, Step: 9/17, Loss: 0.0002
# Epoch: 277/300, Step: 10/17, Loss: 0.0002
# Epoch: 277/300, Step: 11/17, Loss: 0.0001
# Epoch: 277/300, Step: 12/17, Loss: 0.0001
# Epoch: 277/300, Step: 13/17, Loss: 0.0001
# Epoch: 277/300, Step: 14/17, Loss: 0.0002
# Epoch: 277/300, Step: 15/17, Loss: 0.0002
# Epoch: 277/300, Step: 16/17, Loss: 0.0001
# Epoch: 278/300, Step: 1/17, Loss: 0.0002
# Epoch: 278/300, Step: 2/17, Loss: 0.0001
# Epoch: 278/300, Step: 3/17, Loss: 0.0001
# Epoch: 278/300, Step: 4/17, Loss: 0.0001
# Epoch: 278/300, Step: 5/17, Loss: 0.0001
# Epoch: 278/300, Step: 6/17, Loss: 0.0001
# Epoch: 278/300, Step: 7/17, Loss: 0.0001
# Epoch: 278/300, Step: 8/17, Loss: 0.0001
# Epoch: 278/300, Step: 9/17, Loss: 0.0002
# Epoch: 278/300, Step: 10/17, Loss: 0.0002
# Epoch: 278/300, Step: 11/17, Loss: 0.0001
# Epoch: 278/300, Step: 12/17, Loss: 0.0002
# Epoch: 278/300, Step: 13/17, Loss: 0.0001
# Epoch: 278/300, Step: 14/17, Loss: 0.0001
# Epoch: 278/300, Step: 15/17, Loss: 0.0001
# Epoch: 278/300, Step: 16/17, Loss: 0.0001
# Epoch: 279/300, Step: 1/17, Loss: 0.0001
# Epoch: 279/300, Step: 2/17, Loss: 0.0002
# Epoch: 279/300, Step: 3/17, Loss: 0.0002
# Epoch: 279/300, Step: 4/17, Loss: 0.0002
# Epoch: 279/300, Step: 5/17, Loss: 0.0001
# Epoch: 279/300, Step: 6/17, Loss: 0.0002
# Epoch: 279/300, Step: 7/17, Loss: 0.0002
# Epoch: 279/300, Step: 8/17, Loss: 0.0002
# Epoch: 279/300, Step: 9/17, Loss: 0.0001
# Epoch: 279/300, Step: 10/17, Loss: 0.0001
# Epoch: 279/300, Step: 11/17, Loss: 0.0001
# Epoch: 279/300, Step: 12/17, Loss: 0.0002
# Epoch: 279/300, Step: 13/17, Loss: 0.0001
# Epoch: 279/300, Step: 14/17, Loss: 0.0002
# Epoch: 279/300, Step: 15/17, Loss: 0.0001
# Epoch: 279/300, Step: 16/17, Loss: 0.0002
# Epoch: 280/300, Step: 1/17, Loss: 0.0001
# Epoch: 280/300, Step: 2/17, Loss: 0.0002
# Epoch: 280/300, Step: 3/17, Loss: 0.0001
# Epoch: 280/300, Step: 4/17, Loss: 0.0002
# Epoch: 280/300, Step: 5/17, Loss: 0.0001
# Epoch: 280/300, Step: 6/17, Loss: 0.0001
# Epoch: 280/300, Step: 7/17, Loss: 0.0002
# Epoch: 280/300, Step: 8/17, Loss: 0.0001
# Epoch: 280/300, Step: 9/17, Loss: 0.0001
# Epoch: 280/300, Step: 10/17, Loss: 0.0002
# Epoch: 280/300, Step: 11/17, Loss: 0.0002
# Epoch: 280/300, Step: 12/17, Loss: 0.0001
# Epoch: 280/300, Step: 13/17, Loss: 0.0001
# Epoch: 280/300, Step: 14/17, Loss: 0.0001
# Epoch: 280/300, Step: 15/17, Loss: 0.0002
# Epoch: 280/300, Step: 16/17, Loss: 0.0001
# Epoch: 281/300, Step: 1/17, Loss: 0.0002
# Epoch: 281/300, Step: 2/17, Loss: 0.0001
# Epoch: 281/300, Step: 3/17, Loss: 0.0001
# Epoch: 281/300, Step: 4/17, Loss: 0.0002
# Epoch: 281/300, Step: 5/17, Loss: 0.0001
# Epoch: 281/300, Step: 6/17, Loss: 0.0002
# Epoch: 281/300, Step: 7/17, Loss: 0.0001
# Epoch: 281/300, Step: 8/17, Loss: 0.0002
# Epoch: 281/300, Step: 9/17, Loss: 0.0001
# Epoch: 281/300, Step: 10/17, Loss: 0.0001
# Epoch: 281/300, Step: 11/17, Loss: 0.0002
# Epoch: 281/300, Step: 12/17, Loss: 0.0001
# Epoch: 281/300, Step: 13/17, Loss: 0.0002
# Epoch: 281/300, Step: 14/17, Loss: 0.0002
# Epoch: 281/300, Step: 15/17, Loss: 0.0002
# Epoch: 281/300, Step: 16/17, Loss: 0.0001
# Epoch: 282/300, Step: 1/17, Loss: 0.0001
# Epoch: 282/300, Step: 2/17, Loss: 0.0001
# Epoch: 282/300, Step: 3/17, Loss: 0.0001
# Epoch: 282/300, Step: 4/17, Loss: 0.0001
# Epoch: 282/300, Step: 5/17, Loss: 0.0001
# Epoch: 282/300, Step: 6/17, Loss: 0.0002
# Epoch: 282/300, Step: 7/17, Loss: 0.0001
# Epoch: 282/300, Step: 8/17, Loss: 0.0001
# Epoch: 282/300, Step: 9/17, Loss: 0.0002
# Epoch: 282/300, Step: 10/17, Loss: 0.0002
# Epoch: 282/300, Step: 11/17, Loss: 0.0002
# Epoch: 282/300, Step: 12/17, Loss: 0.0001
# Epoch: 282/300, Step: 13/17, Loss: 0.0001
# Epoch: 282/300, Step: 14/17, Loss: 0.0002
# Epoch: 282/300, Step: 15/17, Loss: 0.0001
# Epoch: 282/300, Step: 16/17, Loss: 0.0001
# Epoch: 283/300, Step: 1/17, Loss: 0.0001
# Epoch: 283/300, Step: 2/17, Loss: 0.0001
# Epoch: 283/300, Step: 3/17, Loss: 0.0002
# Epoch: 283/300, Step: 4/17, Loss: 0.0001
# Epoch: 283/300, Step: 5/17, Loss: 0.0001
# Epoch: 283/300, Step: 6/17, Loss: 0.0002
# Epoch: 283/300, Step: 7/17, Loss: 0.0001
# Epoch: 283/300, Step: 8/17, Loss: 0.0001
# Epoch: 283/300, Step: 9/17, Loss: 0.0001
# Epoch: 283/300, Step: 10/17, Loss: 0.0002
# Epoch: 283/300, Step: 11/17, Loss: 0.0001
# Epoch: 283/300, Step: 12/17, Loss: 0.0001
# Epoch: 283/300, Step: 13/17, Loss: 0.0001
# Epoch: 283/300, Step: 14/17, Loss: 0.0001
# Epoch: 283/300, Step: 15/17, Loss: 0.0001
# Epoch: 283/300, Step: 16/17, Loss: 0.0001
# Epoch: 284/300, Step: 1/17, Loss: 0.0001
# Epoch: 284/300, Step: 2/17, Loss: 0.0001
# Epoch: 284/300, Step: 3/17, Loss: 0.0001
# Epoch: 284/300, Step: 4/17, Loss: 0.0002
# Epoch: 284/300, Step: 5/17, Loss: 0.0001
# Epoch: 284/300, Step: 6/17, Loss: 0.0001
# Epoch: 284/300, Step: 7/17, Loss: 0.0001
# Epoch: 284/300, Step: 8/17, Loss: 0.0001
# Epoch: 284/300, Step: 9/17, Loss: 0.0001
# Epoch: 284/300, Step: 10/17, Loss: 0.0001
# Epoch: 284/300, Step: 11/17, Loss: 0.0002
# Epoch: 284/300, Step: 12/17, Loss: 0.0001
# Epoch: 284/300, Step: 13/17, Loss: 0.0001
# Epoch: 284/300, Step: 14/17, Loss: 0.0001
# Epoch: 284/300, Step: 15/17, Loss: 0.0001
# Epoch: 284/300, Step: 16/17, Loss: 0.0001
# Epoch: 285/300, Step: 1/17, Loss: 0.0001
# Epoch: 285/300, Step: 2/17, Loss: 0.0001
# Epoch: 285/300, Step: 3/17, Loss: 0.0002
# Epoch: 285/300, Step: 4/17, Loss: 0.0001
# Epoch: 285/300, Step: 5/17, Loss: 0.0001
# Epoch: 285/300, Step: 6/17, Loss: 0.0001
# Epoch: 285/300, Step: 7/17, Loss: 0.0002
# Epoch: 285/300, Step: 8/17, Loss: 0.0001
# Epoch: 285/300, Step: 9/17, Loss: 0.0001
# Epoch: 285/300, Step: 10/17, Loss: 0.0002
# Epoch: 285/300, Step: 11/17, Loss: 0.0001
# Epoch: 285/300, Step: 12/17, Loss: 0.0001
# Epoch: 285/300, Step: 13/17, Loss: 0.0001
# Epoch: 285/300, Step: 14/17, Loss: 0.0002
# Epoch: 285/300, Step: 15/17, Loss: 0.0001
# Epoch: 285/300, Step: 16/17, Loss: 0.0001
# Epoch: 286/300, Step: 1/17, Loss: 0.0002
# Epoch: 286/300, Step: 2/17, Loss: 0.0002
# Epoch: 286/300, Step: 3/17, Loss: 0.0001
# Epoch: 286/300, Step: 4/17, Loss: 0.0002
# Epoch: 286/300, Step: 5/17, Loss: 0.0001
# Epoch: 286/300, Step: 6/17, Loss: 0.0001
# Epoch: 286/300, Step: 7/17, Loss: 0.0001
# Epoch: 286/300, Step: 8/17, Loss: 0.0001
# Epoch: 286/300, Step: 9/17, Loss: 0.0001
# Epoch: 286/300, Step: 10/17, Loss: 0.0001
# Epoch: 286/300, Step: 11/17, Loss: 0.0001
# Epoch: 286/300, Step: 12/17, Loss: 0.0001
# Epoch: 286/300, Step: 13/17, Loss: 0.0001
# Epoch: 286/300, Step: 14/17, Loss: 0.0002
# Epoch: 286/300, Step: 15/17, Loss: 0.0001
# Epoch: 286/300, Step: 16/17, Loss: 0.0001
# Epoch: 287/300, Step: 1/17, Loss: 0.0002
# Epoch: 287/300, Step: 2/17, Loss: 0.0002
# Epoch: 287/300, Step: 3/17, Loss: 0.0002
# Epoch: 287/300, Step: 4/17, Loss: 0.0001
# Epoch: 287/300, Step: 5/17, Loss: 0.0001
# Epoch: 287/300, Step: 6/17, Loss: 0.0001
# Epoch: 287/300, Step: 7/17, Loss: 0.0001
# Epoch: 287/300, Step: 8/17, Loss: 0.0001
# Epoch: 287/300, Step: 9/17, Loss: 0.0001
# Epoch: 287/300, Step: 10/17, Loss: 0.0001
# Epoch: 287/300, Step: 11/17, Loss: 0.0002
# Epoch: 287/300, Step: 12/17, Loss: 0.0001
# Epoch: 287/300, Step: 13/17, Loss: 0.0001
# Epoch: 287/300, Step: 14/17, Loss: 0.0001
# Epoch: 287/300, Step: 15/17, Loss: 0.0001
# Epoch: 287/300, Step: 16/17, Loss: 0.0001
# Epoch: 288/300, Step: 1/17, Loss: 0.0001
# Epoch: 288/300, Step: 2/17, Loss: 0.0001
# Epoch: 288/300, Step: 3/17, Loss: 0.0002
# Epoch: 288/300, Step: 4/17, Loss: 0.0001
# Epoch: 288/300, Step: 5/17, Loss: 0.0001
# Epoch: 288/300, Step: 6/17, Loss: 0.0001
# Epoch: 288/300, Step: 7/17, Loss: 0.0001
# Epoch: 288/300, Step: 8/17, Loss: 0.0001
# Epoch: 288/300, Step: 9/17, Loss: 0.0001
# Epoch: 288/300, Step: 10/17, Loss: 0.0001
# Epoch: 288/300, Step: 11/17, Loss: 0.0001
# Epoch: 288/300, Step: 12/17, Loss: 0.0002
# Epoch: 288/300, Step: 13/17, Loss: 0.0001
# Epoch: 288/300, Step: 14/17, Loss: 0.0001
# Epoch: 288/300, Step: 15/17, Loss: 0.0001
# Epoch: 288/300, Step: 16/17, Loss: 0.0001
# Epoch: 289/300, Step: 1/17, Loss: 0.0001
# Epoch: 289/300, Step: 2/17, Loss: 0.0001
# Epoch: 289/300, Step: 3/17, Loss: 0.0001
# Epoch: 289/300, Step: 4/17, Loss: 0.0001
# Epoch: 289/300, Step: 5/17, Loss: 0.0001
# Epoch: 289/300, Step: 6/17, Loss: 0.0001
# Epoch: 289/300, Step: 7/17, Loss: 0.0001
# Epoch: 289/300, Step: 8/17, Loss: 0.0001
# Epoch: 289/300, Step: 9/17, Loss: 0.0002
# Epoch: 289/300, Step: 10/17, Loss: 0.0001
# Epoch: 289/300, Step: 11/17, Loss: 0.0001
# Epoch: 289/300, Step: 12/17, Loss: 0.0001
# Epoch: 289/300, Step: 13/17, Loss: 0.0001
# Epoch: 289/300, Step: 14/17, Loss: 0.0001
# Epoch: 289/300, Step: 15/17, Loss: 0.0001
# Epoch: 289/300, Step: 16/17, Loss: 0.0001
# Epoch: 290/300, Step: 1/17, Loss: 0.0001
# Epoch: 290/300, Step: 2/17, Loss: 0.0001
# Epoch: 290/300, Step: 3/17, Loss: 0.0001
# Epoch: 290/300, Step: 4/17, Loss: 0.0001
# Epoch: 290/300, Step: 5/17, Loss: 0.0001
# Epoch: 290/300, Step: 6/17, Loss: 0.0001
# Epoch: 290/300, Step: 7/17, Loss: 0.0001
# Epoch: 290/300, Step: 8/17, Loss: 0.0001
# Epoch: 290/300, Step: 9/17, Loss: 0.0001
# Epoch: 290/300, Step: 10/17, Loss: 0.0001
# Epoch: 290/300, Step: 11/17, Loss: 0.0001
# Epoch: 290/300, Step: 12/17, Loss: 0.0001
# Epoch: 290/300, Step: 13/17, Loss: 0.0001
# Epoch: 290/300, Step: 14/17, Loss: 0.0001
# Epoch: 290/300, Step: 15/17, Loss: 0.0001
# Epoch: 290/300, Step: 16/17, Loss: 0.0001
# Epoch: 291/300, Step: 1/17, Loss: 0.0001
# Epoch: 291/300, Step: 2/17, Loss: 0.0001
# Epoch: 291/300, Step: 3/17, Loss: 0.0001
# Epoch: 291/300, Step: 4/17, Loss: 0.0001
# Epoch: 291/300, Step: 5/17, Loss: 0.0001
# Epoch: 291/300, Step: 6/17, Loss: 0.0001
# Epoch: 291/300, Step: 7/17, Loss: 0.0001
# Epoch: 291/300, Step: 8/17, Loss: 0.0001
# Epoch: 291/300, Step: 9/17, Loss: 0.0001
# Epoch: 291/300, Step: 10/17, Loss: 0.0001
# Epoch: 291/300, Step: 11/17, Loss: 0.0001
# Epoch: 291/300, Step: 12/17, Loss: 0.0001
# Epoch: 291/300, Step: 13/17, Loss: 0.0001
# Epoch: 291/300, Step: 14/17, Loss: 0.0001
# Epoch: 291/300, Step: 15/17, Loss: 0.0001
# Epoch: 291/300, Step: 16/17, Loss: 0.0001
# Epoch: 292/300, Step: 1/17, Loss: 0.0001
# Epoch: 292/300, Step: 2/17, Loss: 0.0001
# Epoch: 292/300, Step: 3/17, Loss: 0.0001
# Epoch: 292/300, Step: 4/17, Loss: 0.0001
# Epoch: 292/300, Step: 5/17, Loss: 0.0001
# Epoch: 292/300, Step: 6/17, Loss: 0.0001
# Epoch: 292/300, Step: 7/17, Loss: 0.0001
# Epoch: 292/300, Step: 8/17, Loss: 0.0001
# Epoch: 292/300, Step: 9/17, Loss: 0.0001
# Epoch: 292/300, Step: 10/17, Loss: 0.0001
# Epoch: 292/300, Step: 11/17, Loss: 0.0001
# Epoch: 292/300, Step: 12/17, Loss: 0.0001
# Epoch: 292/300, Step: 13/17, Loss: 0.0002
# Epoch: 292/300, Step: 14/17, Loss: 0.0001
# Epoch: 292/300, Step: 15/17, Loss: 0.0001
# Epoch: 292/300, Step: 16/17, Loss: 0.0001
# Epoch: 293/300, Step: 1/17, Loss: 0.0001
# Epoch: 293/300, Step: 2/17, Loss: 0.0001
# Epoch: 293/300, Step: 3/17, Loss: 0.0001
# Epoch: 293/300, Step: 4/17, Loss: 0.0001
# Epoch: 293/300, Step: 5/17, Loss: 0.0001
# Epoch: 293/300, Step: 6/17, Loss: 0.0001
# Epoch: 293/300, Step: 7/17, Loss: 0.0001
# Epoch: 293/300, Step: 8/17, Loss: 0.0001
# Epoch: 293/300, Step: 9/17, Loss: 0.0001
# Epoch: 293/300, Step: 10/17, Loss: 0.0001
# Epoch: 293/300, Step: 11/17, Loss: 0.0001
# Epoch: 293/300, Step: 12/17, Loss: 0.0001
# Epoch: 293/300, Step: 13/17, Loss: 0.0001
# Epoch: 293/300, Step: 14/17, Loss: 0.0001
# Epoch: 293/300, Step: 15/17, Loss: 0.0001
# Epoch: 293/300, Step: 16/17, Loss: 0.0001
# Epoch: 294/300, Step: 1/17, Loss: 0.0001
# Epoch: 294/300, Step: 2/17, Loss: 0.0001
# Epoch: 294/300, Step: 3/17, Loss: 0.0001
# Epoch: 294/300, Step: 4/17, Loss: 0.0001
# Epoch: 294/300, Step: 5/17, Loss: 0.0002
# Epoch: 294/300, Step: 6/17, Loss: 0.0001
# Epoch: 294/300, Step: 7/17, Loss: 0.0001
# Epoch: 294/300, Step: 8/17, Loss: 0.0001
# Epoch: 294/300, Step: 9/17, Loss: 0.0001
# Epoch: 294/300, Step: 10/17, Loss: 0.0001
# Epoch: 294/300, Step: 11/17, Loss: 0.0001
# Epoch: 294/300, Step: 12/17, Loss: 0.0001
# Epoch: 294/300, Step: 13/17, Loss: 0.0001
# Epoch: 294/300, Step: 14/17, Loss: 0.0001
# Epoch: 294/300, Step: 15/17, Loss: 0.0001
# Epoch: 294/300, Step: 16/17, Loss: 0.0001
# Epoch: 295/300, Step: 1/17, Loss: 0.0001
# Epoch: 295/300, Step: 2/17, Loss: 0.0001
# Epoch: 295/300, Step: 3/17, Loss: 0.0001
# Epoch: 295/300, Step: 4/17, Loss: 0.0001
# Epoch: 295/300, Step: 5/17, Loss: 0.0001
# Epoch: 295/300, Step: 6/17, Loss: 0.0001
# Epoch: 295/300, Step: 7/17, Loss: 0.0002
# Epoch: 295/300, Step: 8/17, Loss: 0.0001
# Epoch: 295/300, Step: 9/17, Loss: 0.0001
# Epoch: 295/300, Step: 10/17, Loss: 0.0001
# Epoch: 295/300, Step: 11/17, Loss: 0.0001
# Epoch: 295/300, Step: 12/17, Loss: 0.0001
# Epoch: 295/300, Step: 13/17, Loss: 0.0001
# Epoch: 295/300, Step: 14/17, Loss: 0.0001
# Epoch: 295/300, Step: 15/17, Loss: 0.0001
# Epoch: 295/300, Step: 16/17, Loss: 0.0001
# Epoch: 296/300, Step: 1/17, Loss: 0.0001
# Epoch: 296/300, Step: 2/17, Loss: 0.0001
# Epoch: 296/300, Step: 3/17, Loss: 0.0001
# Epoch: 296/300, Step: 4/17, Loss: 0.0001
# Epoch: 296/300, Step: 5/17, Loss: 0.0001
# Epoch: 296/300, Step: 6/17, Loss: 0.0001
# Epoch: 296/300, Step: 7/17, Loss: 0.0001
# Epoch: 296/300, Step: 8/17, Loss: 0.0001
# Epoch: 296/300, Step: 9/17, Loss: 0.0001
# Epoch: 296/300, Step: 10/17, Loss: 0.0001
# Epoch: 296/300, Step: 11/17, Loss: 0.0001
# Epoch: 296/300, Step: 12/17, Loss: 0.0001
# Epoch: 296/300, Step: 13/17, Loss: 0.0001
# Epoch: 296/300, Step: 14/17, Loss: 0.0001
# Epoch: 296/300, Step: 15/17, Loss: 0.0001
# Epoch: 296/300, Step: 16/17, Loss: 0.0001
# Epoch: 297/300, Step: 1/17, Loss: 0.0001
# Epoch: 297/300, Step: 2/17, Loss: 0.0001
# Epoch: 297/300, Step: 3/17, Loss: 0.0001
# Epoch: 297/300, Step: 4/17, Loss: 0.0001
# Epoch: 297/300, Step: 5/17, Loss: 0.0001
# Epoch: 297/300, Step: 6/17, Loss: 0.0001
# Epoch: 297/300, Step: 7/17, Loss: 0.0001
# Epoch: 297/300, Step: 8/17, Loss: 0.0001
# Epoch: 297/300, Step: 9/17, Loss: 0.0001
# Epoch: 297/300, Step: 10/17, Loss: 0.0001
# Epoch: 297/300, Step: 11/17, Loss: 0.0001
# Epoch: 297/300, Step: 12/17, Loss: 0.0001
# Epoch: 297/300, Step: 13/17, Loss: 0.0001
# Epoch: 297/300, Step: 14/17, Loss: 0.0001
# Epoch: 297/300, Step: 15/17, Loss: 0.0001
# Epoch: 297/300, Step: 16/17, Loss: 0.0001
# Epoch: 298/300, Step: 1/17, Loss: 0.0001
# Epoch: 298/300, Step: 2/17, Loss: 0.0001
# Epoch: 298/300, Step: 3/17, Loss: 0.0001
# Epoch: 298/300, Step: 4/17, Loss: 0.0001
# Epoch: 298/300, Step: 5/17, Loss: 0.0001
# Epoch: 298/300, Step: 6/17, Loss: 0.0001
# Epoch: 298/300, Step: 7/17, Loss: 0.0001
# Epoch: 298/300, Step: 8/17, Loss: 0.0001
# Epoch: 298/300, Step: 9/17, Loss: 0.0001
# Epoch: 298/300, Step: 10/17, Loss: 0.0001
# Epoch: 298/300, Step: 11/17, Loss: 0.0001
# Epoch: 298/300, Step: 12/17, Loss: 0.0001
# Epoch: 298/300, Step: 13/17, Loss: 0.0001
# Epoch: 298/300, Step: 14/17, Loss: 0.0001
# Epoch: 298/300, Step: 15/17, Loss: 0.0001
# Epoch: 298/300, Step: 16/17, Loss: 0.0001
# Epoch: 299/300, Step: 1/17, Loss: 0.0001
# Epoch: 299/300, Step: 2/17, Loss: 0.0001
# Epoch: 299/300, Step: 3/17, Loss: 0.0001
# Epoch: 299/300, Step: 4/17, Loss: 0.0001
# Epoch: 299/300, Step: 5/17, Loss: 0.0001
# Epoch: 299/300, Step: 6/17, Loss: 0.0001
# Epoch: 299/300, Step: 7/17, Loss: 0.0001
# Epoch: 299/300, Step: 8/17, Loss: 0.0001
# Epoch: 299/300, Step: 9/17, Loss: 0.0001
# Epoch: 299/300, Step: 10/17, Loss: 0.0001
# Epoch: 299/300, Step: 11/17, Loss: 0.0001
# Epoch: 299/300, Step: 12/17, Loss: 0.0001
# Epoch: 299/300, Step: 13/17, Loss: 0.0001
# Epoch: 299/300, Step: 14/17, Loss: 0.0001
# Epoch: 299/300, Step: 15/17, Loss: 0.0001
# Epoch: 299/300, Step: 16/17, Loss: 0.0001
# Epoch: 300/300, Step: 1/17, Loss: 0.0001
# Epoch: 300/300, Step: 2/17, Loss: 0.0001
# Epoch: 300/300, Step: 3/17, Loss: 0.0001
# Epoch: 300/300, Step: 4/17, Loss: 0.0001
# Epoch: 300/300, Step: 5/17, Loss: 0.0001
# Epoch: 300/300, Step: 6/17, Loss: 0.0001
# Epoch: 300/300, Step: 7/17, Loss: 0.0001
# Epoch: 300/300, Step: 8/17, Loss: 0.0001
# Epoch: 300/300, Step: 9/17, Loss: 0.0001
# Epoch: 300/300, Step: 10/17, Loss: 0.0001
# Epoch: 300/300, Step: 11/17, Loss: 0.0001
# Epoch: 300/300, Step: 12/17, Loss: 0.0001
# Epoch: 300/300, Step: 13/17, Loss: 0.0001
# Epoch: 300/300, Step: 14/17, Loss: 0.0001
# Epoch: 300/300, Step: 15/17, Loss: 0.0001
# Epoch: 300/300, Step: 16/17, Loss: 0.0001
# Training completed !!!

# %%
# Inference

def inference(seq2seq, input, max_len=7):
    # truncate the input to max_len of training samples and remove the unknown tokens
    input = input[:max_len]  
    input = [token for token in input if vocab_asr.dig2idx(token) != UNK_token]                        
    encoded_seq = [SOS_token] + vocab_asr.encode(input) + [EOS_token]
    
    # one-hot encode the input
    one_hot_enc = np.zeros((1, len(encoded_seq), vocab_asr.vocab_size()))
    for i, token in enumerate(encoded_seq):
        one_hot_enc[0, i, token] = 1
        
    one_hot_enc = torch.tensor(one_hot_enc, dtype=torch.float).to(device)
    decoded_seq = seq2seq.predict(one_hot_enc)
    decoded_seq = torch.argmax(decoded_seq, dim=2).flatten().tolist()
    
    decoded_seq = [token for token in decoded_seq if token not in [SOS_token, EOS_token]]
    
    return vocab_mt.decode(decoded_seq)

# %%
# Test the model
seq2seq.eval()

input_seq = "O123456"
output_seq = inference(seq2seq, input_seq)

print("Input sequence : {}".format(input_seq))
print("Output sequence : {}".format(output_seq))
# Out:
# Input sequence : O123456
# Output sequence : பூஜ்யம் ஒன்று இரண்டு மூன்று நான்கு ஐந்து ஆறு

# %%
# Save the model
# torch.save(seq2seq.state_dict(), "seq2seq.pth")
